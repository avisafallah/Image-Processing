# %% [markdown]
# ##Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/ImageProcessing/HW3/Dataset
import cv2
import cv2 as cv
import numpy as np
import os
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
import keras.utils as image
import random
import math
import shutil
import pathlib
from pathlib import Path
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
from sklearn.metrics import confusion_matrix,precision_score,recall_score,ConfusionMatrixDisplay,roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn import metrics
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from keras.utils import np_utils
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Dense,Flatten,Activation
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Activation, Dropout, Conv2D, ZeroPadding2D,MaxPooling2D,Input
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
from tensorflow.keras.optimizers import Adam,SGD
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/ImageProcessing/HW3/Dataset
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
data = []
images_dir = '/content/drive/MyDrive/ImageProcessing/HW3/Dataset/dataset'
for filename in os.listdir(images_dir):
    if filename.endswith(".tif"):
        img_path = os.path.join(images_dir, filename)
        img_id = filename.split('_')[0][2:]
        label = int(filename.split('_')[1].split('.')[0])
        data.append((img_path, label))

D_F = pd.DataFrame(data, columns=['image', 'label'])
print(D_F)
# Out:
#                                                  image  label
# 0    /content/drive/MyDrive/ImageProcessing/HW3/Dat...      0
# 1    /content/drive/MyDrive/ImageProcessing/HW3/Dat...      0
# 2    /content/drive/MyDrive/ImageProcessing/HW3/Dat...      0
# 3    /content/drive/MyDrive/ImageProcessing/HW3/Dat...      0
# 4    /content/drive/MyDrive/ImageProcessing/HW3/Dat...      0
# ..                                                 ...    ...
# 255  /content/drive/MyDrive/ImageProcessing/HW3/Dat...      1
# 256  /content/drive/MyDrive/ImageProcessing/HW3/Dat...      1
# 257  /content/drive/MyDrive/ImageProcessing/HW3/Dat...      1
# 258  /content/drive/MyDrive/ImageProcessing/HW3/Dat...      1
# 259  /content/drive/MyDrive/ImageProcessing/HW3/Dat...      1
#
# [260 rows x 2 columns]

# %%
def data_preprocessing(dataframe, dim):
    n = dataframe.shape[0]
    images = np.zeros((n, dim, dim, 3), dtype=np.float32)
    labels = np.zeros((n, 2), dtype=np.float32)

    for i, (_, row) in enumerate(dataframe.iterrows()):
        img = cv2.imread(str(row['image']))
        img = cv2.resize(img, (dim, dim))
        encoded_label = np_utils.to_categorical(row['label'], num_classes=2)
        orig_img = img.astype(np.float32) / 255.
        images[i] = orig_img
        labels[i] = encoded_label

    return images, labels

dim = 257
images, labels = data_preprocessing(D_F, dim)
print(f'Images shape: {images.shape}')
print(f'Labels shape: {labels.shape}')
# Out:
# Images shape: (260, 257, 257, 3)
# Labels shape: (260, 2)

# %%
seed = 369
np.random.seed(seed)

# %% [markdown]
# ##Seperate 60% of the dataset for training , 20% for test and 20% for validation

# %%
# Splitting the data into train, validation, and test sets
train_ratio = 0.6
val_ratio = 0.2
test_ratio = 0.2

x , y = images, labels

x_train_val, x_test, y_train_val, y_test = train_test_split(x, y, test_size=test_ratio, stratify=y, random_state=seed)
x_train, x_val, y_train, y_val = train_test_split(x_train_val, y_train_val, test_size=val_ratio/(train_ratio+val_ratio),
                                                  stratify=y_train_val, random_state=seed)

# Printing the shapes of the train, validation, and test sets
print(f"X_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_val shape: {x_val.shape}")
print(f"y_val shape: {y_val.shape}")
print(f"X_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (156, 257, 257, 3)
# y_train shape: (156, 2)
# X_val shape: (52, 257, 257, 3)
# y_val shape: (52, 2)
# X_test shape: (52, 257, 257, 3)
# y_test shape: (52, 2)

# %% [markdown]
# ##Create artificial images with data augmentation and add them to our dataset

# %%
Batch_S = 100
N_epochs = 500
LR = 0.0001

# %%
# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

training_data = datagen.flow(x_train, y_train, batch_size=Batch_S)

num_train_samples = x_train.shape[0]
total_augmented_images = num_train_samples * Batch_S

print("Total augmented images per original image:", total_augmented_images)
# Out:
# Total augmented images per original image: 15600

# %%
# Number of images in the train, validation, and test sets
print("Train set:")
print("Number of images:", x_train.shape[0])

print("Validation set:")
print("Number of images:", x_val.shape[0])

print("Test set:")
print("Number of images:", x_test.shape[0])

# Total number of augmented images
num_train_samples = x_train.shape[0]
batch_size = Batch_S
total_augmented_images = num_train_samples * batch_size

print("Total augmented images after augmentation:", total_augmented_images)

# Total number of images after augmentation
total_images = total_augmented_images + x_train.shape[0] + x_val.shape[0] +  x_test.shape[0]
print("Total images after augmentation:", total_images)
# Out:
# Train set:
# Number of images: 156
# Validation set:
# Number of images: 52
# Test set:
# Number of images: 52
# Total augmented images after augmentation: 15600
# Total images after augmentation: 15860

# %% [markdown]
# ##Create a convolutional neural network (CNN)

# %%
model = Sequential()

# Convolutional layers

model.add(Input(shape=(257, 257, 3)))

model.add(ZeroPadding2D(padding=(2, 2)))
model.add(Conv2D(48, (3, 3), strides=(2, 2), padding='valid'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(ZeroPadding2D(padding=(2, 2)))
model.add(Conv2D(48, (3, 3), strides=(1, 1), padding='valid'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(ZeroPadding2D(padding=(3, 3)))
model.add(Conv2D(48, (5, 5), strides=(1, 1), padding='valid'))
model.add(Activation('relu'))

model.add(ZeroPadding2D(padding=(2, 2)))
model.add(Conv2D(48, (3, 3), strides=(1, 1), padding='valid'))
model.add(Activation('relu'))

model.add(ZeroPadding2D(padding=(2, 2)))
model.add(Conv2D(48, (3, 3), strides=(1, 1), padding='valid'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))

# Fully connected layers
model.add(Flatten())
model.add(Dense(1000))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(2))
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  zero_padding2d_25 (ZeroPadd  (None, 261, 261, 3)      0
#  ing2D)
#
#  conv2d_25 (Conv2D)          (None, 130, 130, 48)      1344
#
#  activation_35 (Activation)  (None, 130, 130, 48)      0
#
#  max_pooling2d_15 (MaxPoolin  (None, 65, 65, 48)       0
#  g2D)
#
#  zero_padding2d_26 (ZeroPadd  (None, 69, 69, 48)       0
#  ing2D)
#
#  conv2d_26 (Conv2D)          (None, 67, 67, 48)        20784
#
#  activation_36 (Activation)  (None, 67, 67, 48)        0
#
#  max_pooling2d_16 (MaxPoolin  (None, 33, 33, 48)       0
#  g2D)
#
#  zero_padding2d_27 (ZeroPadd  (None, 39, 39, 48)       0
#  ing2D)
#
#  conv2d_27 (Conv2D)          (None, 35, 35, 48)        57648
#
#  activation_37 (Activation)  (None, 35, 35, 48)        0
#
#  zero_padding2d_28 (ZeroPadd  (None, 39, 39, 48)       0
#  ing2D)
#
#  conv2d_28 (Conv2D)          (None, 37, 37, 48)        20784
#
#  activation_38 (Activation)  (None, 37, 37, 48)        0
#
#  zero_padding2d_29 (ZeroPadd  (None, 41, 41, 48)       0
#  ing2D)
#
#  conv2d_29 (Conv2D)          (None, 39, 39, 48)        20784
#
#  activation_39 (Activation)  (None, 39, 39, 48)        0
#
#  max_pooling2d_17 (MaxPoolin  (None, 19, 19, 48)       0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 17328)             0
#
#  dense_10 (Dense)            (None, 1000)              17329000
#
#  activation_40 (Activation)  (None, 1000)              0
#
#  dropout_5 (Dropout)         (None, 1000)              0
#
#  dense_11 (Dense)            (None, 2)                 2002
#
#  activation_41 (Activation)  (None, 2)                 0
#
# =================================================================
# Total params: 17,452,346
# Trainable params: 17,452,346
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# ##Training the model

# %%
optimizer = Adam(learning_rate=LR)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath="best_weights.hdf5", monitor = 'val_accuracy',verbose=1, save_weights_only=True)

# %%
history = model.fit(
    training_data,
    epochs= N_epochs,
    validation_data= (x_val, y_val),
    steps_per_epoch= x_train.shape[0] / Batch_S,
    verbose=1,
    callbacks=[checkpointer])
# Out:
# Epoch 1/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6974 - accuracy: 0.5000
# Epoch 1: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 1s/step - loss: 0.6974 - accuracy: 0.5000 - val_loss: 0.6913 - val_accuracy: 0.5000
# Epoch 2/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6899 - accuracy: 0.5000
# Epoch 2: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.6899 - accuracy: 0.5000 - val_loss: 0.6883 - val_accuracy: 0.5000
# Epoch 3/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6872 - accuracy: 0.5385
# Epoch 3: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.6872 - accuracy: 0.5385 - val_loss: 0.6843 - val_accuracy: 0.5000
# Epoch 4/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6819 - accuracy: 0.5449
# Epoch 4: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.6819 - accuracy: 0.5449 - val_loss: 0.6792 - val_accuracy: 0.5192
# Epoch 5/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6730 - accuracy: 0.5897
# Epoch 5: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.6730 - accuracy: 0.5897 - val_loss: 0.6723 - val_accuracy: 0.5769
# Epoch 6/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6651 - accuracy: 0.6538
# Epoch 6: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.6651 - accuracy: 0.6538 - val_loss: 0.6630 - val_accuracy: 0.5769
# Epoch 7/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6491 - accuracy: 0.6859
# Epoch 7: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.6491 - accuracy: 0.6859 - val_loss: 0.6509 - val_accuracy: 0.6346
# Epoch 8/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6338 - accuracy: 0.7115
# Epoch 8: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.6338 - accuracy: 0.7115 - val_loss: 0.6365 - val_accuracy: 0.7115
# Epoch 9/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6119 - accuracy: 0.7756
# Epoch 9: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.6119 - accuracy: 0.7756 - val_loss: 0.6198 - val_accuracy: 0.6346
# Epoch 10/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5994 - accuracy: 0.7500
# Epoch 10: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.5994 - accuracy: 0.7500 - val_loss: 0.6105 - val_accuracy: 0.6731
# Epoch 11/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5829 - accuracy: 0.7179
# Epoch 11: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.5829 - accuracy: 0.7179 - val_loss: 0.5818 - val_accuracy: 0.6923
# Epoch 12/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5550 - accuracy: 0.7756
# Epoch 12: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.5550 - accuracy: 0.7756 - val_loss: 0.5931 - val_accuracy: 0.6731
# Epoch 13/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5390 - accuracy: 0.7115
# Epoch 13: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.5390 - accuracy: 0.7115 - val_loss: 0.5464 - val_accuracy: 0.6731
# Epoch 14/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4939 - accuracy: 0.8141
# Epoch 14: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.4939 - accuracy: 0.8141 - val_loss: 0.5341 - val_accuracy: 0.7500
# Epoch 15/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5291 - accuracy: 0.7308
# Epoch 15: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.5291 - accuracy: 0.7308 - val_loss: 0.5585 - val_accuracy: 0.7115
# Epoch 16/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4949 - accuracy: 0.7436
# Epoch 16: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.4949 - accuracy: 0.7436 - val_loss: 0.5110 - val_accuracy: 0.6923
# Epoch 17/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4653 - accuracy: 0.7756
# Epoch 17: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.4653 - accuracy: 0.7756 - val_loss: 0.5075 - val_accuracy: 0.7500
# Epoch 18/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4665 - accuracy: 0.7756
# Epoch 18: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.4665 - accuracy: 0.7756 - val_loss: 0.5167 - val_accuracy: 0.6731
# Epoch 19/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4649 - accuracy: 0.7885
# Epoch 19: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.4649 - accuracy: 0.7885 - val_loss: 0.4898 - val_accuracy: 0.7500
# Epoch 20/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4785 - accuracy: 0.7500
# Epoch 20: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 2s/step - loss: 0.4785 - accuracy: 0.7500 - val_loss: 0.4871 - val_accuracy: 0.7115
# Epoch 21/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4540 - accuracy: 0.7692
# Epoch 21: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.4540 - accuracy: 0.7692 - val_loss: 0.4871 - val_accuracy: 0.6923
# Epoch 22/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4278 - accuracy: 0.8013
# Epoch 22: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.4278 - accuracy: 0.8013 - val_loss: 0.4901 - val_accuracy: 0.6923
# Epoch 23/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4538 - accuracy: 0.8077
# Epoch 23: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.4538 - accuracy: 0.8077 - val_loss: 0.4741 - val_accuracy: 0.7500
# Epoch 24/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4345 - accuracy: 0.7949
# Epoch 24: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 3s/step - loss: 0.4345 - accuracy: 0.7949 - val_loss: 0.4813 - val_accuracy: 0.6923
# Epoch 25/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4527 - accuracy: 0.7821
# Epoch 25: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.4527 - accuracy: 0.7821 - val_loss: 0.4865 - val_accuracy: 0.6731
# Epoch 26/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4550 - accuracy: 0.7756
# Epoch 26: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.4550 - accuracy: 0.7756 - val_loss: 0.4620 - val_accuracy: 0.7692
# Epoch 27/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4206 - accuracy: 0.8013
# Epoch 27: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.4206 - accuracy: 0.8013 - val_loss: 0.4729 - val_accuracy: 0.7692
# Epoch 28/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4517 - accuracy: 0.7821
# Epoch 28: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.4517 - accuracy: 0.7821 - val_loss: 0.4852 - val_accuracy: 0.7115
# Epoch 29/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4291 - accuracy: 0.7756
# Epoch 29: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 3s/step - loss: 0.4291 - accuracy: 0.7756 - val_loss: 0.4579 - val_accuracy: 0.7308
# Epoch 30/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3931 - accuracy: 0.8141
# Epoch 30: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 3s/step - loss: 0.3931 - accuracy: 0.8141 - val_loss: 0.4626 - val_accuracy: 0.7500
# Epoch 31/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4055 - accuracy: 0.8013
# Epoch 31: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.4055 - accuracy: 0.8013 - val_loss: 0.4510 - val_accuracy: 0.7692
# Epoch 32/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4242 - accuracy: 0.7821
# Epoch 32: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.4242 - accuracy: 0.7821 - val_loss: 0.4851 - val_accuracy: 0.7308
# Epoch 33/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4050 - accuracy: 0.7885
# Epoch 33: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 3s/step - loss: 0.4050 - accuracy: 0.7885 - val_loss: 0.4491 - val_accuracy: 0.7500
# Epoch 34/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4500 - accuracy: 0.7821
# Epoch 34: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.4500 - accuracy: 0.7821 - val_loss: 0.4483 - val_accuracy: 0.7500
# Epoch 35/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4064 - accuracy: 0.8141
# Epoch 35: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.4064 - accuracy: 0.8141 - val_loss: 0.4556 - val_accuracy: 0.7308
# Epoch 36/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4292 - accuracy: 0.7821
# Epoch 36: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.4292 - accuracy: 0.7821 - val_loss: 0.4847 - val_accuracy: 0.7500
# Epoch 37/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4454 - accuracy: 0.7821
# Epoch 37: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.4454 - accuracy: 0.7821 - val_loss: 0.4597 - val_accuracy: 0.8077
# Epoch 38/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4380 - accuracy: 0.7821
# Epoch 38: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.4380 - accuracy: 0.7821 - val_loss: 0.4464 - val_accuracy: 0.7692
# Epoch 39/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3916 - accuracy: 0.8013
# Epoch 39: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.3916 - accuracy: 0.8013 - val_loss: 0.4809 - val_accuracy: 0.7500
# Epoch 40/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4474 - accuracy: 0.7885
# Epoch 40: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.4474 - accuracy: 0.7885 - val_loss: 0.4645 - val_accuracy: 0.7885
# Epoch 41/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4049 - accuracy: 0.8205
# Epoch 41: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.4049 - accuracy: 0.8205 - val_loss: 0.4397 - val_accuracy: 0.7500
# Epoch 42/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3938 - accuracy: 0.8141
# Epoch 42: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.3938 - accuracy: 0.8141 - val_loss: 0.4288 - val_accuracy: 0.7692
# Epoch 43/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4102 - accuracy: 0.7821
# Epoch 43: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.4102 - accuracy: 0.7821 - val_loss: 0.4636 - val_accuracy: 0.7692
# Epoch 44/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4235 - accuracy: 0.8141
# Epoch 44: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.4235 - accuracy: 0.8141 - val_loss: 0.4405 - val_accuracy: 0.7500
# Epoch 45/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4457 - accuracy: 0.7885
# Epoch 45: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.4457 - accuracy: 0.7885 - val_loss: 0.4234 - val_accuracy: 0.7692
# Epoch 46/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3829 - accuracy: 0.8269
# Epoch 46: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.3829 - accuracy: 0.8269 - val_loss: 0.4203 - val_accuracy: 0.7692
# Epoch 47/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4211 - accuracy: 0.8077
# Epoch 47: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.4211 - accuracy: 0.8077 - val_loss: 0.4373 - val_accuracy: 0.7885
# Epoch 48/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3855 - accuracy: 0.7949
# Epoch 48: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.3855 - accuracy: 0.7949 - val_loss: 0.4202 - val_accuracy: 0.7692
# Epoch 49/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3806 - accuracy: 0.8141
# Epoch 49: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.3806 - accuracy: 0.8141 - val_loss: 0.4151 - val_accuracy: 0.7692
# Epoch 50/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3685 - accuracy: 0.8077
# Epoch 50: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.3685 - accuracy: 0.8077 - val_loss: 0.4152 - val_accuracy: 0.7692
# Epoch 51/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3586 - accuracy: 0.8462
# Epoch 51: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.3586 - accuracy: 0.8462 - val_loss: 0.4223 - val_accuracy: 0.7692
# Epoch 52/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3811 - accuracy: 0.7885
# Epoch 52: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.3811 - accuracy: 0.7885 - val_loss: 0.4090 - val_accuracy: 0.7692
# Epoch 53/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3668 - accuracy: 0.8526
# Epoch 53: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.3668 - accuracy: 0.8526 - val_loss: 0.4062 - val_accuracy: 0.7692
# Epoch 54/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3593 - accuracy: 0.8333
# Epoch 54: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 2s/step - loss: 0.3593 - accuracy: 0.8333 - val_loss: 0.4220 - val_accuracy: 0.7692
# Epoch 55/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3677 - accuracy: 0.8269
# Epoch 55: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.3677 - accuracy: 0.8269 - val_loss: 0.4101 - val_accuracy: 0.7692
# Epoch 56/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3552 - accuracy: 0.8333
# Epoch 56: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.3552 - accuracy: 0.8333 - val_loss: 0.3986 - val_accuracy: 0.7692
# Epoch 57/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3697 - accuracy: 0.8205
# Epoch 57: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.3697 - accuracy: 0.8205 - val_loss: 0.3941 - val_accuracy: 0.7692
# Epoch 58/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3871 - accuracy: 0.8269
# Epoch 58: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 3s/step - loss: 0.3871 - accuracy: 0.8269 - val_loss: 0.4104 - val_accuracy: 0.7885
# Epoch 59/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3718 - accuracy: 0.8397
# Epoch 59: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.3718 - accuracy: 0.8397 - val_loss: 0.3896 - val_accuracy: 0.7692
# Epoch 60/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3560 - accuracy: 0.8462
# Epoch 60: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.3560 - accuracy: 0.8462 - val_loss: 0.3917 - val_accuracy: 0.7885
# Epoch 61/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4059 - accuracy: 0.8141
# Epoch 61: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.4059 - accuracy: 0.8141 - val_loss: 0.3945 - val_accuracy: 0.7692
# Epoch 62/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3420 - accuracy: 0.8333
# Epoch 62: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.3420 - accuracy: 0.8333 - val_loss: 0.3888 - val_accuracy: 0.7692
# Epoch 63/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3655 - accuracy: 0.8462
# Epoch 63: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 5s/step - loss: 0.3655 - accuracy: 0.8462 - val_loss: 0.3846 - val_accuracy: 0.7692
# Epoch 64/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3416 - accuracy: 0.8269
# Epoch 64: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.3416 - accuracy: 0.8269 - val_loss: 0.3796 - val_accuracy: 0.7885
# Epoch 65/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3234 - accuracy: 0.8590
# Epoch 65: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.3234 - accuracy: 0.8590 - val_loss: 0.3771 - val_accuracy: 0.7692
# Epoch 66/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3443 - accuracy: 0.8077
# Epoch 66: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.3443 - accuracy: 0.8077 - val_loss: 0.3800 - val_accuracy: 0.7692
# Epoch 67/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3341 - accuracy: 0.8013
# Epoch 67: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.3341 - accuracy: 0.8013 - val_loss: 0.3732 - val_accuracy: 0.7885
# Epoch 68/500
# 2/1 [======================================] - ETA: -1s - loss: 0.3457 - accuracy: 0.8269
# Epoch 68: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 5s/step - loss: 0.3457 - accuracy: 0.8269 - val_loss: 0.3708 - val_accuracy: 0.7885
# Epoch 69/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3488 - accuracy: 0.8141
# Epoch 69: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.3488 - accuracy: 0.8141 - val_loss: 0.3722 - val_accuracy: 0.7692
# Epoch 70/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3125 - accuracy: 0.8462
# Epoch 70: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.3125 - accuracy: 0.8462 - val_loss: 0.3698 - val_accuracy: 0.7885
# Epoch 71/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3525 - accuracy: 0.8333
# Epoch 71: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.3525 - accuracy: 0.8333 - val_loss: 0.3626 - val_accuracy: 0.7885
# Epoch 72/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3388 - accuracy: 0.8462
# Epoch 72: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.3388 - accuracy: 0.8462 - val_loss: 0.3651 - val_accuracy: 0.8077
# Epoch 73/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3491 - accuracy: 0.8462
# Epoch 73: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.3491 - accuracy: 0.8462 - val_loss: 0.3744 - val_accuracy: 0.8654
# Epoch 74/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3189 - accuracy: 0.8718
# Epoch 74: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.3189 - accuracy: 0.8718 - val_loss: 0.3587 - val_accuracy: 0.8077
# Epoch 75/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3361 - accuracy: 0.8462
# Epoch 75: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.3361 - accuracy: 0.8462 - val_loss: 0.3487 - val_accuracy: 0.8077
# Epoch 76/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3136 - accuracy: 0.8269
# Epoch 76: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.3136 - accuracy: 0.8269 - val_loss: 0.3801 - val_accuracy: 0.8654
# Epoch 77/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3084 - accuracy: 0.8526
# Epoch 77: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.3084 - accuracy: 0.8526 - val_loss: 0.3414 - val_accuracy: 0.8077
# Epoch 78/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3290 - accuracy: 0.8077
# Epoch 78: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.3290 - accuracy: 0.8077 - val_loss: 0.3416 - val_accuracy: 0.7885
# Epoch 79/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2888 - accuracy: 0.8846
# Epoch 79: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.2888 - accuracy: 0.8846 - val_loss: 0.3412 - val_accuracy: 0.7885
# Epoch 80/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2868 - accuracy: 0.8718
# Epoch 80: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.2868 - accuracy: 0.8718 - val_loss: 0.3444 - val_accuracy: 0.7885
# Epoch 81/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2975 - accuracy: 0.8526
# Epoch 81: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.2975 - accuracy: 0.8526 - val_loss: 0.3367 - val_accuracy: 0.7885
# Epoch 82/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2967 - accuracy: 0.8462
# Epoch 82: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.2967 - accuracy: 0.8462 - val_loss: 0.3276 - val_accuracy: 0.8077
# Epoch 83/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2898 - accuracy: 0.8654
# Epoch 83: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.2898 - accuracy: 0.8654 - val_loss: 0.3222 - val_accuracy: 0.8269
# Epoch 84/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2954 - accuracy: 0.8718
# Epoch 84: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.2954 - accuracy: 0.8718 - val_loss: 0.3232 - val_accuracy: 0.8654
# Epoch 85/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2857 - accuracy: 0.8910
# Epoch 85: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.2857 - accuracy: 0.8910 - val_loss: 0.3156 - val_accuracy: 0.7885
# Epoch 86/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2644 - accuracy: 0.8846
# Epoch 86: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.2644 - accuracy: 0.8846 - val_loss: 0.3165 - val_accuracy: 0.7885
# Epoch 87/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2793 - accuracy: 0.8590
# Epoch 87: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.2793 - accuracy: 0.8590 - val_loss: 0.3175 - val_accuracy: 0.8846
# Epoch 88/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2830 - accuracy: 0.8846
# Epoch 88: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.2830 - accuracy: 0.8846 - val_loss: 0.2957 - val_accuracy: 0.8654
# Epoch 89/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2609 - accuracy: 0.8974
# Epoch 89: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.2609 - accuracy: 0.8974 - val_loss: 0.2913 - val_accuracy: 0.8462
# Epoch 90/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2575 - accuracy: 0.8846
# Epoch 90: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.2575 - accuracy: 0.8846 - val_loss: 0.2908 - val_accuracy: 0.8462
# Epoch 91/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2418 - accuracy: 0.9038
# Epoch 91: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.2418 - accuracy: 0.9038 - val_loss: 0.2982 - val_accuracy: 0.8654
# Epoch 92/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2362 - accuracy: 0.8974
# Epoch 92: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.2362 - accuracy: 0.8974 - val_loss: 0.2910 - val_accuracy: 0.8269
# Epoch 93/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2648 - accuracy: 0.8718
# Epoch 93: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.2648 - accuracy: 0.8718 - val_loss: 0.2672 - val_accuracy: 0.8654
# Epoch 94/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2300 - accuracy: 0.9295
# Epoch 94: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 2s/step - loss: 0.2300 - accuracy: 0.9295 - val_loss: 0.2769 - val_accuracy: 0.9231
# Epoch 95/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2629 - accuracy: 0.8846
# Epoch 95: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.2629 - accuracy: 0.8846 - val_loss: 0.2631 - val_accuracy: 0.8269
# Epoch 96/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2234 - accuracy: 0.9038
# Epoch 96: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.2234 - accuracy: 0.9038 - val_loss: 0.2561 - val_accuracy: 0.8846
# Epoch 97/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2530 - accuracy: 0.9103
# Epoch 97: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.2530 - accuracy: 0.9103 - val_loss: 0.2680 - val_accuracy: 0.9231
# Epoch 98/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2308 - accuracy: 0.9167
# Epoch 98: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.2308 - accuracy: 0.9167 - val_loss: 0.2509 - val_accuracy: 0.8654
# Epoch 99/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2157 - accuracy: 0.8910
# Epoch 99: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 2s/step - loss: 0.2157 - accuracy: 0.8910 - val_loss: 0.2322 - val_accuracy: 0.9423
# Epoch 100/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2149 - accuracy: 0.8974
# Epoch 100: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.2149 - accuracy: 0.8974 - val_loss: 0.2325 - val_accuracy: 0.9231
# Epoch 101/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1942 - accuracy: 0.9423
# Epoch 101: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.1942 - accuracy: 0.9423 - val_loss: 0.2265 - val_accuracy: 0.8846
# Epoch 102/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2215 - accuracy: 0.9038
# Epoch 102: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.2215 - accuracy: 0.9038 - val_loss: 0.2256 - val_accuracy: 0.8654
# Epoch 103/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1741 - accuracy: 0.9231
# Epoch 103: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.1741 - accuracy: 0.9231 - val_loss: 0.2030 - val_accuracy: 0.9231
# Epoch 104/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1700 - accuracy: 0.9487
# Epoch 104: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.1700 - accuracy: 0.9487 - val_loss: 0.2489 - val_accuracy: 0.8846
# Epoch 105/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1789 - accuracy: 0.9295
# Epoch 105: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.1789 - accuracy: 0.9295 - val_loss: 0.2027 - val_accuracy: 0.9038
# Epoch 106/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1550 - accuracy: 0.9295
# Epoch 106: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.1550 - accuracy: 0.9295 - val_loss: 0.1880 - val_accuracy: 0.9615
# Epoch 107/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1432 - accuracy: 0.9744
# Epoch 107: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.1432 - accuracy: 0.9744 - val_loss: 0.2200 - val_accuracy: 0.9038
# Epoch 108/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1396 - accuracy: 0.9808
# Epoch 108: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.1396 - accuracy: 0.9808 - val_loss: 0.1714 - val_accuracy: 0.9231
# Epoch 109/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1696 - accuracy: 0.9295
# Epoch 109: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.1696 - accuracy: 0.9295 - val_loss: 0.1605 - val_accuracy: 0.9615
# Epoch 110/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2128 - accuracy: 0.8974
# Epoch 110: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 4s/step - loss: 0.2128 - accuracy: 0.8974 - val_loss: 0.1971 - val_accuracy: 0.9231
# Epoch 111/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1148 - accuracy: 0.9615
# Epoch 111: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.1148 - accuracy: 0.9615 - val_loss: 0.1790 - val_accuracy: 0.9038
# Epoch 112/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1555 - accuracy: 0.9423
# Epoch 112: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.1555 - accuracy: 0.9423 - val_loss: 0.1909 - val_accuracy: 0.9231
# Epoch 113/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1340 - accuracy: 0.9615
# Epoch 113: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.1340 - accuracy: 0.9615 - val_loss: 0.1629 - val_accuracy: 0.9615
# Epoch 114/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1081 - accuracy: 0.9615
# Epoch 114: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.1081 - accuracy: 0.9615 - val_loss: 0.1360 - val_accuracy: 0.9615
# Epoch 115/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1270 - accuracy: 0.9423
# Epoch 115: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.1270 - accuracy: 0.9423 - val_loss: 0.1640 - val_accuracy: 0.9615
# Epoch 116/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0952 - accuracy: 0.9936
# Epoch 116: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.0952 - accuracy: 0.9936 - val_loss: 0.2120 - val_accuracy: 0.9038
# Epoch 117/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9808
# Epoch 117: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.1082 - accuracy: 0.9808 - val_loss: 0.1229 - val_accuracy: 0.9808
# Epoch 118/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1310 - accuracy: 0.9359
# Epoch 118: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.1310 - accuracy: 0.9359 - val_loss: 0.1229 - val_accuracy: 0.9615
# Epoch 119/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1060 - accuracy: 0.9679
# Epoch 119: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.1060 - accuracy: 0.9679 - val_loss: 0.2317 - val_accuracy: 0.9038
# Epoch 120/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1625 - accuracy: 0.9679
# Epoch 120: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.1625 - accuracy: 0.9679 - val_loss: 0.1349 - val_accuracy: 0.9808
# Epoch 121/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0909 - accuracy: 0.9744
# Epoch 121: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0909 - accuracy: 0.9744 - val_loss: 0.1431 - val_accuracy: 0.9615
# Epoch 122/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0963 - accuracy: 0.9808
# Epoch 122: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.0963 - accuracy: 0.9808 - val_loss: 0.1202 - val_accuracy: 0.9808
# Epoch 123/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0756 - accuracy: 0.9679
# Epoch 123: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 2s/step - loss: 0.0756 - accuracy: 0.9679 - val_loss: 0.1219 - val_accuracy: 0.9808
# Epoch 124/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9808
# Epoch 124: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0744 - accuracy: 0.9808 - val_loss: 0.1440 - val_accuracy: 0.9808
# Epoch 125/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0739 - accuracy: 0.9744
# Epoch 125: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0739 - accuracy: 0.9744 - val_loss: 0.1425 - val_accuracy: 0.9808
# Epoch 126/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0654 - accuracy: 0.9744
# Epoch 126: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0654 - accuracy: 0.9744 - val_loss: 0.1109 - val_accuracy: 0.9808
# Epoch 127/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0512 - accuracy: 0.9872
# Epoch 127: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.0512 - accuracy: 0.9872 - val_loss: 0.1051 - val_accuracy: 0.9808
# Epoch 128/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0805 - accuracy: 0.9744
# Epoch 128: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 4s/step - loss: 0.0805 - accuracy: 0.9744 - val_loss: 0.1243 - val_accuracy: 0.9808
# Epoch 129/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0561 - accuracy: 0.9808
# Epoch 129: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0561 - accuracy: 0.9808 - val_loss: 0.1089 - val_accuracy: 0.9808
# Epoch 130/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0842 - accuracy: 0.9808
# Epoch 130: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0842 - accuracy: 0.9808 - val_loss: 0.1965 - val_accuracy: 0.9423
# Epoch 131/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0732 - accuracy: 0.9808
# Epoch 131: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0732 - accuracy: 0.9808 - val_loss: 0.1065 - val_accuracy: 0.9808
# Epoch 132/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9872
# Epoch 132: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.0618 - accuracy: 0.9872 - val_loss: 0.0982 - val_accuracy: 0.9808
# Epoch 133/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0740 - accuracy: 0.9744
# Epoch 133: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 2s/step - loss: 0.0740 - accuracy: 0.9744 - val_loss: 0.2145 - val_accuracy: 0.9231
# Epoch 134/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0685 - accuracy: 0.9872
# Epoch 134: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0685 - accuracy: 0.9872 - val_loss: 0.1466 - val_accuracy: 0.9615
# Epoch 135/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0696 - accuracy: 0.9744
# Epoch 135: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.0696 - accuracy: 0.9744 - val_loss: 0.0971 - val_accuracy: 0.9808
# Epoch 136/500
# 2/1 [======================================] - ETA: -1s - loss: 0.0754 - accuracy: 0.9679
# Epoch 136: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 5s/step - loss: 0.0754 - accuracy: 0.9679 - val_loss: 0.1669 - val_accuracy: 0.9423
# Epoch 137/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0520 - accuracy: 0.9936
# Epoch 137: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0520 - accuracy: 0.9936 - val_loss: 0.0939 - val_accuracy: 0.9808
# Epoch 138/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9808
# Epoch 138: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0631 - accuracy: 0.9808 - val_loss: 0.1097 - val_accuracy: 0.9808
# Epoch 139/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0693 - accuracy: 0.9936
# Epoch 139: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0693 - accuracy: 0.9936 - val_loss: 0.1562 - val_accuracy: 0.9423
# Epoch 140/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9744
# Epoch 140: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.0613 - accuracy: 0.9744 - val_loss: 0.1144 - val_accuracy: 0.9808
# Epoch 141/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9872
# Epoch 141: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0404 - accuracy: 0.9872 - val_loss: 0.1404 - val_accuracy: 0.9615
# Epoch 142/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0608 - accuracy: 0.9872
# Epoch 142: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0608 - accuracy: 0.9872 - val_loss: 0.1279 - val_accuracy: 0.9808
# Epoch 143/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0439 - accuracy: 0.9936
# Epoch 143: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0439 - accuracy: 0.9936 - val_loss: 0.1327 - val_accuracy: 0.9808
# Epoch 144/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9936
# Epoch 144: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.0378 - accuracy: 0.9936 - val_loss: 0.1015 - val_accuracy: 0.9808
# Epoch 145/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9936
# Epoch 145: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0370 - accuracy: 0.9936 - val_loss: 0.0956 - val_accuracy: 0.9808
# Epoch 146/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0444 - accuracy: 0.9936
# Epoch 146: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.0444 - accuracy: 0.9936 - val_loss: 0.1677 - val_accuracy: 0.9615
# Epoch 147/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9872
# Epoch 147: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0518 - accuracy: 0.9872 - val_loss: 0.0946 - val_accuracy: 0.9808
# Epoch 148/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0634 - accuracy: 0.9808
# Epoch 148: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.0634 - accuracy: 0.9808 - val_loss: 0.0815 - val_accuracy: 0.9808
# Epoch 149/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0622 - accuracy: 0.9808
# Epoch 149: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 4s/step - loss: 0.0622 - accuracy: 0.9808 - val_loss: 0.2814 - val_accuracy: 0.9231
# Epoch 150/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0611 - accuracy: 0.9679
# Epoch 150: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0611 - accuracy: 0.9679 - val_loss: 0.0919 - val_accuracy: 0.9808
# Epoch 151/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0473 - accuracy: 0.9744
# Epoch 151: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0473 - accuracy: 0.9744 - val_loss: 0.0932 - val_accuracy: 0.9808
# Epoch 152/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0563 - accuracy: 0.9744
# Epoch 152: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0563 - accuracy: 0.9744 - val_loss: 0.2032 - val_accuracy: 0.9423
# Epoch 153/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0557 - accuracy: 0.9936
# Epoch 153: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0557 - accuracy: 0.9936 - val_loss: 0.0875 - val_accuracy: 0.9808
# Epoch 154/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9808
# Epoch 154: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0349 - accuracy: 0.9808 - val_loss: 0.0883 - val_accuracy: 0.9808
# Epoch 155/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0626 - accuracy: 0.9744
# Epoch 155: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0626 - accuracy: 0.9744 - val_loss: 0.1495 - val_accuracy: 0.9615
# Epoch 156/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0229 - accuracy: 1.0000
# Epoch 156: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 0.0971 - val_accuracy: 0.9808
# Epoch 157/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0376 - accuracy: 0.9936
# Epoch 157: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.0376 - accuracy: 0.9936 - val_loss: 0.0858 - val_accuracy: 0.9808
# Epoch 158/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9872
# Epoch 158: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0387 - accuracy: 0.9872 - val_loss: 0.1262 - val_accuracy: 0.9808
# Epoch 159/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0194 - accuracy: 1.0000
# Epoch 159: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9615
# Epoch 160/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0364 - accuracy: 0.9872
# Epoch 160: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0364 - accuracy: 0.9872 - val_loss: 0.1132 - val_accuracy: 0.9808
# Epoch 161/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9872
# Epoch 161: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.0329 - accuracy: 0.9872 - val_loss: 0.1267 - val_accuracy: 0.9808
# Epoch 162/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0337 - accuracy: 1.0000
# Epoch 162: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0337 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9808
# Epoch 163/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0624 - accuracy: 0.9936
# Epoch 163: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0624 - accuracy: 0.9936 - val_loss: 0.0850 - val_accuracy: 0.9808
# Epoch 164/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0527 - accuracy: 0.9936
# Epoch 164: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0527 - accuracy: 0.9936 - val_loss: 0.0944 - val_accuracy: 0.9615
# Epoch 165/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0451 - accuracy: 0.9872
# Epoch 165: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.0451 - accuracy: 0.9872 - val_loss: 0.1357 - val_accuracy: 0.9423
# Epoch 166/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0465 - accuracy: 1.0000
# Epoch 166: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 2s/step - loss: 0.0465 - accuracy: 1.0000 - val_loss: 0.1024 - val_accuracy: 0.9808
# Epoch 167/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0379 - accuracy: 0.9872
# Epoch 167: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0379 - accuracy: 0.9872 - val_loss: 0.0968 - val_accuracy: 0.9808
# Epoch 168/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0220 - accuracy: 1.0000
# Epoch 168: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.1859 - val_accuracy: 0.9423
# Epoch 169/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9936
# Epoch 169: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0236 - accuracy: 0.9936 - val_loss: 0.1430 - val_accuracy: 0.9615
# Epoch 170/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9872
# Epoch 170: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 3s/step - loss: 0.0257 - accuracy: 0.9872 - val_loss: 0.0844 - val_accuracy: 0.9808
# Epoch 171/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0472 - accuracy: 0.9808
# Epoch 171: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0472 - accuracy: 0.9808 - val_loss: 0.0984 - val_accuracy: 0.9808
# Epoch 172/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9808
# Epoch 172: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0474 - accuracy: 0.9808 - val_loss: 0.2114 - val_accuracy: 0.9423
# Epoch 173/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0290 - accuracy: 1.0000
# Epoch 173: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.0794 - val_accuracy: 0.9808
# Epoch 174/500
# 2/1 [======================================] - ETA: -1s - loss: 0.0353 - accuracy: 0.9808
# Epoch 174: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 5s/step - loss: 0.0353 - accuracy: 0.9808 - val_loss: 0.1007 - val_accuracy: 0.9808
# Epoch 175/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0153 - accuracy: 1.0000
# Epoch 175: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9808
# Epoch 176/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0267 - accuracy: 1.0000
# Epoch 176: saving model to best_weights.hdf5
# ...
# Epoch 443/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 443: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9808
# Epoch 444/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9936
# Epoch 444: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0142 - accuracy: 0.9936 - val_loss: 0.1324 - val_accuracy: 0.9808
# Epoch 445/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 445: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9808
# Epoch 446/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 446: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9808
# Epoch 447/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 447: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9808
# Epoch 448/500
# 2/1 [======================================] - ETA: 0s - loss: 9.1140e-04 - accuracy: 1.0000
# Epoch 448: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 9.1140e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9808
# Epoch 449/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 449: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9808
# Epoch 450/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0108 - accuracy: 1.0000
# Epoch 450: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.1285 - val_accuracy: 0.9808
# Epoch 451/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 451: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1594 - val_accuracy: 0.9808
# Epoch 452/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 452: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1854 - val_accuracy: 0.9808
# Epoch 453/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9936
# Epoch 453: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0144 - accuracy: 0.9936 - val_loss: 0.1461 - val_accuracy: 0.9808
# Epoch 454/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 454: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 0.9808
# Epoch 455/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0472 - accuracy: 0.9744
# Epoch 455: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 3s/step - loss: 0.0472 - accuracy: 0.9744 - val_loss: 0.1784 - val_accuracy: 0.9808
# Epoch 456/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0959 - accuracy: 0.9615
# Epoch 456: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0959 - accuracy: 0.9615 - val_loss: 0.2469 - val_accuracy: 0.9423
# Epoch 457/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9936
# Epoch 457: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0193 - accuracy: 0.9936 - val_loss: 0.0425 - val_accuracy: 0.9615
# Epoch 458/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0690 - accuracy: 0.9744
# Epoch 458: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0690 - accuracy: 0.9744 - val_loss: 0.0666 - val_accuracy: 0.9808
# Epoch 459/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 459: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.2229 - val_accuracy: 0.9808
# Epoch 460/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9936
# Epoch 460: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0238 - accuracy: 0.9936 - val_loss: 0.2906 - val_accuracy: 0.9423
# Epoch 461/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0494 - accuracy: 0.9872
# Epoch 461: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0494 - accuracy: 0.9872 - val_loss: 0.1050 - val_accuracy: 0.9808
# Epoch 462/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0374 - accuracy: 0.9808
# Epoch 462: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0374 - accuracy: 0.9808 - val_loss: 0.0655 - val_accuracy: 0.9808
# Epoch 463/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0634 - accuracy: 0.9744
# Epoch 463: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0634 - accuracy: 0.9744 - val_loss: 0.2919 - val_accuracy: 0.9423
# Epoch 464/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0895 - accuracy: 0.9679
# Epoch 464: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0895 - accuracy: 0.9679 - val_loss: 0.2044 - val_accuracy: 0.9808
# Epoch 465/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0099 - accuracy: 1.0000
# Epoch 465: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.0587 - val_accuracy: 0.9808
# Epoch 466/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9808
# Epoch 466: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0677 - accuracy: 0.9808 - val_loss: 0.0878 - val_accuracy: 0.9808
# Epoch 467/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 467: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2435 - val_accuracy: 0.9615
# Epoch 468/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0578 - accuracy: 0.9872
# Epoch 468: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0578 - accuracy: 0.9872 - val_loss: 0.2469 - val_accuracy: 0.9615
# Epoch 469/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9808
# Epoch 469: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0401 - accuracy: 0.9808 - val_loss: 0.1688 - val_accuracy: 0.9615
# Epoch 470/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1961 - accuracy: 0.9423
# Epoch 470: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.1961 - accuracy: 0.9423 - val_loss: 0.0511 - val_accuracy: 0.9615
# Epoch 471/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9808
# Epoch 471: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.0453 - accuracy: 0.9808 - val_loss: 0.4193 - val_accuracy: 0.9231
# Epoch 472/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9679
# Epoch 472: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.1102 - accuracy: 0.9679 - val_loss: 0.1768 - val_accuracy: 0.9808
# Epoch 473/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 473: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9808
# Epoch 474/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0727 - accuracy: 0.9744
# Epoch 474: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0727 - accuracy: 0.9744 - val_loss: 0.0720 - val_accuracy: 0.9808
# Epoch 475/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0535 - accuracy: 0.9808
# Epoch 475: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0535 - accuracy: 0.9808 - val_loss: 0.2540 - val_accuracy: 0.9615
# Epoch 476/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0620 - accuracy: 0.9679
# Epoch 476: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.0620 - accuracy: 0.9679 - val_loss: 0.2559 - val_accuracy: 0.9423
# Epoch 477/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0165 - accuracy: 1.0000
# Epoch 477: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.1213 - val_accuracy: 0.9808
# Epoch 478/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 478: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9808
# Epoch 479/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0386 - accuracy: 0.9872
# Epoch 479: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0386 - accuracy: 0.9872 - val_loss: 0.1213 - val_accuracy: 0.9615
# Epoch 480/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0366 - accuracy: 0.9744
# Epoch 480: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0366 - accuracy: 0.9744 - val_loss: 0.1395 - val_accuracy: 0.9808
# Epoch 481/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0113 - accuracy: 1.0000
# Epoch 481: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.2222 - val_accuracy: 0.9615
# Epoch 482/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0328 - accuracy: 0.9808
# Epoch 482: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0328 - accuracy: 0.9808 - val_loss: 0.1768 - val_accuracy: 0.9808
# Epoch 483/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 483: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1288 - val_accuracy: 0.9808
# Epoch 484/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0124 - accuracy: 1.0000
# Epoch 484: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.1040 - val_accuracy: 0.9808
# Epoch 485/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9872
# Epoch 485: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0230 - accuracy: 0.9872 - val_loss: 0.1094 - val_accuracy: 0.9808
# Epoch 486/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9936
# Epoch 486: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0199 - accuracy: 0.9936 - val_loss: 0.1304 - val_accuracy: 0.9808
# Epoch 487/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 487: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.1941 - val_accuracy: 0.9615
# Epoch 488/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0076 - accuracy: 1.0000
# Epoch 488: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.2146 - val_accuracy: 0.9615
# Epoch 489/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 489: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.1922 - val_accuracy: 0.9615
# Epoch 490/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 490: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 2s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9808
# Epoch 491/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 491: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9808
# Epoch 492/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 492: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.1141 - val_accuracy: 0.9808
# Epoch 493/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 493: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.1313 - val_accuracy: 0.9808
# Epoch 494/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 494: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 3s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9808
# Epoch 495/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9936
# Epoch 495: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0149 - accuracy: 0.9936 - val_loss: 0.1279 - val_accuracy: 0.9808
# Epoch 496/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 496: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1063 - val_accuracy: 0.9808
# Epoch 497/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0210 - accuracy: 0.9872
# Epoch 497: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0210 - accuracy: 0.9872 - val_loss: 0.1362 - val_accuracy: 0.9808
# Epoch 498/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 498: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 3s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.9808
# Epoch 499/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 499: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9808
# Epoch 500/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 500: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.1322 - val_accuracy: 0.9808

# %%
model.save_weights("model_weights_hist.h5")
model.save("model_hist.h5")

# %% [markdown]
# ##Display variation of each epoch in training accuracy and loss function

# %%
# Extract the training history
training_loss = history.history['loss']
training_accuracy = history.history['accuracy']
validation_loss = history.history['val_loss']
validation_accuracy = history.history['val_accuracy']

# Create a figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(9, 5))

# Plot the training and validation loss
axs[0].plot(range(1, N_epochs + 1), training_loss, label='Training Loss', color='cyan')
axs[0].plot(range(1, N_epochs + 1), validation_loss, label='Validation Loss', color='purple')
axs[0].set_title('Training and Validation Loss')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')
axs[0].legend()

# Plot the training and validation accuracy
axs[1].plot(range(1, N_epochs + 1), training_accuracy, label='Training Accuracy', color='cyan')
axs[1].plot(range(1, N_epochs + 1), validation_accuracy, label='Validation Accuracy', color='purple')
axs[1].set_title('Training and Validation Accuracy')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Accuracy')
axs[1].legend()

# Adjust the spacing between subplots
plt.tight_layout()
# Show the figure
plt.show()

# %% [markdown]
# ##Display model performance metrics

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# Convert true labels to binary format
y_test_binary = np.argmax(y_test, axis=1)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)

# Predict the labels for the test set
y_pred_classes = np.argmax(model.predict(x_test), axis=1)

# Compute model performance metrics
classification_rep = classification_report(y_test_binary, y_pred_classes)
confusion_mat = confusion_matrix(y_test_binary, y_pred_classes)
true_negative, false_positive, _, _ = confusion_mat.ravel()
specificity = true_negative / (true_negative + false_positive)

# Print model performance metrics
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Classification Report:")
print(classification_rep)
print("Confusion Matrix:")
print(confusion_mat)
print("Test Specificity:", specificity)

# Define the class labels
class_labels = ['Normal', 'Abnormal']

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(6, 6))
sns.heatmap(confusion_mat, annot=True, cmap='Blues', fmt='d', xticklabels=class_labels, yticklabels=class_labels)
ax.set_xlabel('Predicted Labels')
ax.set_ylabel('True Labels')
ax.set_title('Confusion Matrix')
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fa62de7f130> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 12ms/step
# Test Loss: 0.05210405960679054
# Test Accuracy: 0.9807692170143127
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        26
#            1       0.96      1.00      0.98        26
#
#     accuracy                           0.98        52
#    macro avg       0.98      0.98      0.98        52
# weighted avg       0.98      0.98      0.98        52
#
# Confusion Matrix:
# [[25  1]
#  [ 0 26]]
# Test Specificity: 0.9615384615384616
