# %% [markdown]
# ##Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/IP/HW3/HW3Model4/datasetmodel4
import cv2
import cv2 as cv
import numpy as np
import os
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
import keras.utils as image
import random
import math
import shutil
import pathlib
from pathlib import Path
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
from sklearn.metrics import confusion_matrix,precision_score,recall_score,ConfusionMatrixDisplay,roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn import metrics
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from keras.utils import np_utils
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Dense,Flatten,Activation
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Activation, Dropout, Conv2D, ZeroPadding2D,MaxPooling2D,Input
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
from tensorflow.keras.optimizers import Adam,SGD
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/IP/HW3/HW3Model4/datasetmodel4
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
data = []
images_dir = '/content/drive/MyDrive/IP/HW3/HW3Model4/datasetmodel4'
for filename in os.listdir(images_dir):
    if filename.endswith(".tif"):
        img_path = os.path.join(images_dir, filename)
        img_id = filename.split('_')[0][2:]
        label = int(filename.split('_')[1].split('.')[0])
        data.append((img_path, label))

D_F = pd.DataFrame(data, columns=['image', 'label'])
print(D_F)
# Out:
#                                                  image  label
# 0    /content/drive/MyDrive/IP/HW3/HW3Model4/datase...      0
# 1    /content/drive/MyDrive/IP/HW3/HW3Model4/datase...      0
# 2    /content/drive/MyDrive/IP/HW3/HW3Model4/datase...      0
# 3    /content/drive/MyDrive/IP/HW3/HW3Model4/datase...      0
# 4    /content/drive/MyDrive/IP/HW3/HW3Model4/datase...      0
# ..                                                 ...    ...
# 255  /content/drive/MyDrive/IP/HW3/HW3Model4/datase...      1
# 256  /content/drive/MyDrive/IP/HW3/HW3Model4/datase...      1
# 257  /content/drive/MyDrive/IP/HW3/HW3Model4/datase...      1
# 258  /content/drive/MyDrive/IP/HW3/HW3Model4/datase...      1
# 259  /content/drive/MyDrive/IP/HW3/HW3Model4/datase...      1
#
# [260 rows x 2 columns]

# %%
def data_preprocessing(dataframe, dim):
    n = dataframe.shape[0]
    images = np.zeros((n, dim, dim, 3), dtype=np.float32)
    labels = np.zeros((n, 2), dtype=np.float32)

    for i, (_, row) in enumerate(dataframe.iterrows()):
        img = cv2.imread(str(row['image']))
        img = cv2.resize(img, (dim, dim))
        encoded_label = np_utils.to_categorical(row['label'], num_classes=2)
        orig_img = img.astype(np.float32) / 255.
        images[i] = orig_img
        labels[i] = encoded_label

    return images, labels

dim = 257
images, labels = data_preprocessing(D_F, dim)
print(f'Images shape: {images.shape}')
print(f'Labels shape: {labels.shape}')
# Out:
# Images shape: (260, 257, 257, 3)
# Labels shape: (260, 2)

# %% [markdown]
# ##Seperate 60% of the dataset for training , 20% for test and 20% for validation

# %%
seed = 369
np.random.seed(seed)

# %%
# Splitting the data into train, validation, and test sets
train_ratio = 0.6
val_ratio = 0.2
test_ratio = 0.2

x , y = images, labels

x_train_val, x_test, y_train_val, y_test = train_test_split(x, y, test_size=test_ratio, stratify=y, random_state=seed)
x_train, x_val, y_train, y_val = train_test_split(x_train_val, y_train_val, test_size=val_ratio/(train_ratio+val_ratio),
                                                  stratify=y_train_val, random_state=seed)

# Printing the shapes of the train, validation, and test sets
print(f"X_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_val shape: {x_val.shape}")
print(f"y_val shape: {y_val.shape}")
print(f"X_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (156, 257, 257, 3)
# y_train shape: (156, 2)
# X_val shape: (52, 257, 257, 3)
# y_val shape: (52, 2)
# X_test shape: (52, 257, 257, 3)
# y_test shape: (52, 2)

# %% [markdown]
# ##Create artificial images with data augmentation and add them to our dataset

# %%
Batch_S = 100
N_epochs = 500
LR = 0.0001

# %%
# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

training_data = datagen.flow(x_train, y_train, batch_size=10)

num_train_samples = x_train.shape[0]
total_augmented_images = num_train_samples * 10

print("Total augmented images per original image:", total_augmented_images)
# Out:
# Total augmented images per original image: 1560

# %%
# Number of images in the train, validation, and test sets
print("Train set:")
print("Number of images:", x_train.shape[0])

print("Validation set:")
print("Number of images:", x_val.shape[0])

print("Test set:")
print("Number of images:", x_test.shape[0])

# Total number of augmented images
num_train_samples = x_train.shape[0]
batch_size = Batch_S
total_augmented_images = num_train_samples * 10

print("Total augmented images after augmentation:", total_augmented_images)

# Total number of images after augmentation
total_images = total_augmented_images + x_train.shape[0] + x_val.shape[0] +  x_test.shape[0]
print("Total images after augmentation:", total_images)
# Out:
# Train set:
# Number of images: 156
# Validation set:
# Number of images: 52
# Test set:
# Number of images: 52
# Total augmented images after augmentation: 1560
# Total images after augmentation: 1820

# %% [markdown]
# ##Create a convolutional neural network (CNN4)

# %%
model4 = Sequential()

# Convolutional layers
model4.add(Conv2D(32, (3, 3), activation='relu', input_shape=(257, 257, 3)))
model4.add(Conv2D(32, (3, 3), activation='relu'))
model4.add(MaxPooling2D(pool_size=(2, 2)))
model4.add(Dropout(0.25))

model4.add(Conv2D(64, (3, 3), activation='relu'))
model4.add(Conv2D(64, (3, 3), activation='relu'))
model4.add(MaxPooling2D(pool_size=(2, 2)))
model4.add(Dropout(0.25))

model4.add(Conv2D(128, (3, 3), activation='relu'))
model4.add(Conv2D(128, (3, 3), activation='relu'))
model4.add(MaxPooling2D(pool_size=(2, 2)))
model4.add(Dropout(0.25))

# Fully connected layers
model4.add(Flatten())
model4.add(Dense(512, activation='relu'))
model4.add(Dropout(0.5))

model4.add(Dense(256, activation='relu'))
model4.add(Dropout(0.5))

model4.add(Dense(2, activation='softmax'))

model4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 255, 255, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 253, 253, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 126, 126, 32)     0
#  )
#
#  dropout (Dropout)           (None, 126, 126, 32)      0
#
#  conv2d_2 (Conv2D)           (None, 124, 124, 64)      18496
#
#  conv2d_3 (Conv2D)           (None, 122, 122, 64)      36928
#
#  max_pooling2d_1 (MaxPooling  (None, 61, 61, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 61, 61, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 59, 59, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 57, 57, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 28, 28, 128)       0
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 512)               51380736
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 51,799,586
# Trainable params: 51,799,586
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model4, show_shapes=True)

# %% [markdown]
# ##Training the model4

# %%
optimizer = Adam(learning_rate=LR)
model4.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath="best_weights.hdf5", monitor = 'val_accuracy',verbose=1, save_weights_only=True)

# %%
history = model4.fit(
    training_data,
    epochs= N_epochs,
    validation_data= (x_val, y_val),
    steps_per_epoch= x_train.shape[0] / Batch_S,
    verbose=1,
    callbacks=[checkpointer])
# Out:
# Epoch 1/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6700 - accuracy: 0.6000
# Epoch 1: saving model to best_weights.hdf5
# 1/1 [==============================] - 19s 7s/step - loss: 0.6700 - accuracy: 0.6000 - val_loss: 0.7073 - val_accuracy: 0.5000
# Epoch 2/500
# 2/1 [======================================] - ETA: 0s - loss: 0.8468 - accuracy: 0.3000
# Epoch 2: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.8468 - accuracy: 0.3000 - val_loss: 0.6927 - val_accuracy: 0.5000
# Epoch 3/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7710 - accuracy: 0.6000
# Epoch 3: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.7710 - accuracy: 0.6000 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 4/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7116 - accuracy: 0.5500
# Epoch 4: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.7116 - accuracy: 0.5500 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 5/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7690 - accuracy: 0.5000
# Epoch 5: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 5s/step - loss: 0.7690 - accuracy: 0.5000 - val_loss: 0.6918 - val_accuracy: 0.5000
# Epoch 6/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7009 - accuracy: 0.4500
# Epoch 6: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.7009 - accuracy: 0.4500 - val_loss: 0.6915 - val_accuracy: 0.5000
# Epoch 7/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6641 - accuracy: 0.7000
# Epoch 7: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.6641 - accuracy: 0.7000 - val_loss: 0.6916 - val_accuracy: 0.5000
# Epoch 8/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6962 - accuracy: 0.5500
# Epoch 8: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.6962 - accuracy: 0.5500 - val_loss: 0.6917 - val_accuracy: 0.5000
# Epoch 9/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7147 - accuracy: 0.5500
# Epoch 9: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.7147 - accuracy: 0.5500 - val_loss: 0.6918 - val_accuracy: 0.5000
# Epoch 10/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7124 - accuracy: 0.4500
# Epoch 10: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.7124 - accuracy: 0.4500 - val_loss: 0.6920 - val_accuracy: 0.5000
# Epoch 11/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6919 - accuracy: 0.4500
# Epoch 11: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.6919 - accuracy: 0.4500 - val_loss: 0.6923 - val_accuracy: 0.5000
# Epoch 12/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7238 - accuracy: 0.4500
# Epoch 12: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.7238 - accuracy: 0.4500 - val_loss: 0.6928 - val_accuracy: 0.5000
# Epoch 13/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6985 - accuracy: 0.5000
# Epoch 13: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.6985 - accuracy: 0.5000 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 14/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6848 - accuracy: 0.4500
# Epoch 14: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.6848 - accuracy: 0.4500 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 15/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7000 - accuracy: 0.5000
# Epoch 15: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.7000 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 16/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6868 - accuracy: 0.5000
# Epoch 16: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6868 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 17/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7002 - accuracy: 0.3500
# Epoch 17: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.7002 - accuracy: 0.3500 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 18/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6872 - accuracy: 0.6500
# Epoch 18: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.6872 - accuracy: 0.6500 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 19/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6927 - accuracy: 0.6000
# Epoch 19: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.6927 - accuracy: 0.6000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 20/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6913 - accuracy: 0.6500
# Epoch 20: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.6913 - accuracy: 0.6500 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 21/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6895 - accuracy: 0.6500
# Epoch 21: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.6895 - accuracy: 0.6500 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 22/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6908 - accuracy: 0.6250
# Epoch 22: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6908 - accuracy: 0.6250 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 23/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6950 - accuracy: 0.4500
# Epoch 23: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.6950 - accuracy: 0.4500 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 24/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6968 - accuracy: 0.4500
# Epoch 24: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.6968 - accuracy: 0.4500 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 25/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6961 - accuracy: 0.4375
# Epoch 25: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.6961 - accuracy: 0.4375 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 26/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6941 - accuracy: 0.6500
# Epoch 26: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6941 - accuracy: 0.6500 - val_loss: 0.6929 - val_accuracy: 0.5000
# Epoch 27/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6895 - accuracy: 0.6000
# Epoch 27: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.6895 - accuracy: 0.6000 - val_loss: 0.6929 - val_accuracy: 0.5000
# Epoch 28/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6962 - accuracy: 0.5000
# Epoch 28: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6962 - accuracy: 0.5000 - val_loss: 0.6929 - val_accuracy: 0.5000
# Epoch 29/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6855 - accuracy: 0.6000
# Epoch 29: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.6855 - accuracy: 0.6000 - val_loss: 0.6928 - val_accuracy: 0.5000
# Epoch 30/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5000
# Epoch 30: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6928 - val_accuracy: 0.5000
# Epoch 31/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6966 - accuracy: 0.4500
# Epoch 31: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.6966 - accuracy: 0.4500 - val_loss: 0.6926 - val_accuracy: 0.5000
# Epoch 32/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6921 - accuracy: 0.6875
# Epoch 32: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.6921 - accuracy: 0.6875 - val_loss: 0.6925 - val_accuracy: 0.5577
# Epoch 33/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6964 - accuracy: 0.3500
# Epoch 33: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6964 - accuracy: 0.3500 - val_loss: 0.6923 - val_accuracy: 0.6346
# Epoch 34/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6829 - accuracy: 0.7000
# Epoch 34: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.6829 - accuracy: 0.7000 - val_loss: 0.6920 - val_accuracy: 0.8269
# Epoch 35/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6895 - accuracy: 0.6500
# Epoch 35: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.6895 - accuracy: 0.6500 - val_loss: 0.6914 - val_accuracy: 0.6731
# Epoch 36/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6910 - accuracy: 0.5500
# Epoch 36: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6910 - accuracy: 0.5500 - val_loss: 0.6914 - val_accuracy: 0.7308
# Epoch 37/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6913 - accuracy: 0.5500
# Epoch 37: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.6913 - accuracy: 0.5500 - val_loss: 0.6911 - val_accuracy: 0.7115
# Epoch 38/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6843 - accuracy: 0.5500
# Epoch 38: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.6843 - accuracy: 0.5500 - val_loss: 0.6905 - val_accuracy: 0.6923
# Epoch 39/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6966 - accuracy: 0.4000
# Epoch 39: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6966 - accuracy: 0.4000 - val_loss: 0.6904 - val_accuracy: 0.8269
# Epoch 40/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5000
# Epoch 40: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.6927 - accuracy: 0.5000 - val_loss: 0.6903 - val_accuracy: 0.7885
# Epoch 41/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6825 - accuracy: 0.8000
# Epoch 41: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.6825 - accuracy: 0.8000 - val_loss: 0.6893 - val_accuracy: 0.7500
# Epoch 42/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6744 - accuracy: 0.6000
# Epoch 42: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6744 - accuracy: 0.6000 - val_loss: 0.6878 - val_accuracy: 0.5962
# Epoch 43/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6739 - accuracy: 0.6500
# Epoch 43: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.6739 - accuracy: 0.6500 - val_loss: 0.6838 - val_accuracy: 0.5000
# Epoch 44/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6695 - accuracy: 0.5000
# Epoch 44: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6695 - accuracy: 0.5000 - val_loss: 0.6798 - val_accuracy: 0.5000
# Epoch 45/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6778 - accuracy: 0.4500
# Epoch 45: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.6778 - accuracy: 0.4500 - val_loss: 0.6767 - val_accuracy: 0.5000
# Epoch 46/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6713 - accuracy: 0.5500
# Epoch 46: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6713 - accuracy: 0.5500 - val_loss: 0.6741 - val_accuracy: 0.5000
# Epoch 47/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6353 - accuracy: 0.6500
# Epoch 47: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.6353 - accuracy: 0.6500 - val_loss: 0.6717 - val_accuracy: 0.5000
# Epoch 48/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7280 - accuracy: 0.4375
# Epoch 48: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.7280 - accuracy: 0.4375 - val_loss: 0.6690 - val_accuracy: 0.5000
# Epoch 49/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6607 - accuracy: 0.6000
# Epoch 49: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.6607 - accuracy: 0.6000 - val_loss: 0.6712 - val_accuracy: 0.5000
# Epoch 50/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7094 - accuracy: 0.4000
# Epoch 50: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.7094 - accuracy: 0.4000 - val_loss: 0.6772 - val_accuracy: 0.5769
# Epoch 51/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6430 - accuracy: 0.8000
# Epoch 51: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.6430 - accuracy: 0.8000 - val_loss: 0.6782 - val_accuracy: 0.6538
# Epoch 52/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6777 - accuracy: 0.5000
# Epoch 52: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.6777 - accuracy: 0.5000 - val_loss: 0.6790 - val_accuracy: 0.7885
# Epoch 53/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6677 - accuracy: 0.6000
# Epoch 53: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.6677 - accuracy: 0.6000 - val_loss: 0.6777 - val_accuracy: 0.7885
# Epoch 54/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6935 - accuracy: 0.5625
# Epoch 54: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6935 - accuracy: 0.5625 - val_loss: 0.6743 - val_accuracy: 0.6346
# Epoch 55/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6438 - accuracy: 0.7500
# Epoch 55: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.6438 - accuracy: 0.7500 - val_loss: 0.6706 - val_accuracy: 0.6154
# Epoch 56/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6918 - accuracy: 0.4000
# Epoch 56: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6918 - accuracy: 0.4000 - val_loss: 0.6678 - val_accuracy: 0.5769
# Epoch 57/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6476 - accuracy: 0.6500
# Epoch 57: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.6476 - accuracy: 0.6500 - val_loss: 0.6640 - val_accuracy: 0.5769
# Epoch 58/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6250 - accuracy: 0.7000
# Epoch 58: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6250 - accuracy: 0.7000 - val_loss: 0.6583 - val_accuracy: 0.5769
# Epoch 59/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6095 - accuracy: 0.6000
# Epoch 59: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6095 - accuracy: 0.6000 - val_loss: 0.6514 - val_accuracy: 0.5769
# Epoch 60/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6872 - accuracy: 0.5000
# Epoch 60: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.6872 - accuracy: 0.5000 - val_loss: 0.6439 - val_accuracy: 0.6154
# Epoch 61/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6343 - accuracy: 0.7500
# Epoch 61: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.6343 - accuracy: 0.7500 - val_loss: 0.6356 - val_accuracy: 0.6154
# Epoch 62/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7097 - accuracy: 0.5000
# Epoch 62: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.7097 - accuracy: 0.5000 - val_loss: 0.6260 - val_accuracy: 0.7885
# Epoch 63/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5993 - accuracy: 0.8125
# Epoch 63: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5993 - accuracy: 0.8125 - val_loss: 0.6393 - val_accuracy: 0.7115
# Epoch 64/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7059 - accuracy: 0.5500
# Epoch 64: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.7059 - accuracy: 0.5500 - val_loss: 0.6396 - val_accuracy: 0.6538
# Epoch 65/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6247 - accuracy: 0.7000
# Epoch 65: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6247 - accuracy: 0.7000 - val_loss: 0.6297 - val_accuracy: 0.7115
# Epoch 66/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6879 - accuracy: 0.6500
# Epoch 66: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.6879 - accuracy: 0.6500 - val_loss: 0.6058 - val_accuracy: 0.8269
# Epoch 67/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5225 - accuracy: 0.8500
# Epoch 67: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.5225 - accuracy: 0.8500 - val_loss: 0.6179 - val_accuracy: 0.5577
# Epoch 68/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6120 - accuracy: 0.6000
# Epoch 68: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.6120 - accuracy: 0.6000 - val_loss: 0.6288 - val_accuracy: 0.5577
# Epoch 69/500
# 2/1 [======================================] - ETA: 0s - loss: 0.8548 - accuracy: 0.4375
# Epoch 69: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.8548 - accuracy: 0.4375 - val_loss: 0.6144 - val_accuracy: 0.6154
# Epoch 70/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4150 - accuracy: 0.9375
# Epoch 70: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.4150 - accuracy: 0.9375 - val_loss: 0.6071 - val_accuracy: 0.6538
# Epoch 71/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6540 - accuracy: 0.6875
# Epoch 71: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6540 - accuracy: 0.6875 - val_loss: 0.6052 - val_accuracy: 0.8269
# Epoch 72/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6257 - accuracy: 0.6000
# Epoch 72: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.6257 - accuracy: 0.6000 - val_loss: 0.6069 - val_accuracy: 0.8462
# Epoch 73/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6118 - accuracy: 0.7000
# Epoch 73: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6118 - accuracy: 0.7000 - val_loss: 0.6148 - val_accuracy: 0.7885
# Epoch 74/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5476 - accuracy: 0.9000
# Epoch 74: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5476 - accuracy: 0.9000 - val_loss: 0.6206 - val_accuracy: 0.7115
# Epoch 75/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6603 - accuracy: 0.5500
# Epoch 75: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 9s/step - loss: 0.6603 - accuracy: 0.5500 - val_loss: 0.6094 - val_accuracy: 0.7692
# Epoch 76/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6996 - accuracy: 0.5000
# Epoch 76: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6996 - accuracy: 0.5000 - val_loss: 0.6038 - val_accuracy: 0.7885
# Epoch 77/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5607 - accuracy: 0.6875
# Epoch 77: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.5607 - accuracy: 0.6875 - val_loss: 0.5858 - val_accuracy: 0.8846
# Epoch 78/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6891 - accuracy: 0.5000
# Epoch 78: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.6891 - accuracy: 0.5000 - val_loss: 0.5823 - val_accuracy: 0.8077
# Epoch 79/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5027 - accuracy: 0.8000
# Epoch 79: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.5027 - accuracy: 0.8000 - val_loss: 0.5848 - val_accuracy: 0.6538
# Epoch 80/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4724 - accuracy: 0.8500
# Epoch 80: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.4724 - accuracy: 0.8500 - val_loss: 0.5880 - val_accuracy: 0.6154
# Epoch 81/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5118 - accuracy: 0.6500
# Epoch 81: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.5118 - accuracy: 0.6500 - val_loss: 0.6052 - val_accuracy: 0.6154
# Epoch 82/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7946 - accuracy: 0.5500
# Epoch 82: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.7946 - accuracy: 0.5500 - val_loss: 0.5925 - val_accuracy: 0.6154
# Epoch 83/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6309 - accuracy: 0.6500
# Epoch 83: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.6309 - accuracy: 0.6500 - val_loss: 0.5621 - val_accuracy: 0.7692
# Epoch 84/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6908 - accuracy: 0.6500
# Epoch 84: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6908 - accuracy: 0.6500 - val_loss: 0.5620 - val_accuracy: 0.7885
# Epoch 85/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6412 - accuracy: 0.7000
# Epoch 85: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6412 - accuracy: 0.7000 - val_loss: 0.5726 - val_accuracy: 0.7885
# Epoch 86/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7748 - accuracy: 0.4500
# Epoch 86: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.7748 - accuracy: 0.4500 - val_loss: 0.5695 - val_accuracy: 0.7692
# Epoch 87/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6638 - accuracy: 0.6000
# Epoch 87: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6638 - accuracy: 0.6000 - val_loss: 0.5666 - val_accuracy: 0.8654
# Epoch 88/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5075 - accuracy: 0.8000
# Epoch 88: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5075 - accuracy: 0.8000 - val_loss: 0.5668 - val_accuracy: 0.8654
# Epoch 89/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5713 - accuracy: 0.8500
# Epoch 89: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5713 - accuracy: 0.8500 - val_loss: 0.5649 - val_accuracy: 0.8846
# Epoch 90/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4375 - accuracy: 1.0000
# Epoch 90: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.4375 - accuracy: 1.0000 - val_loss: 0.5592 - val_accuracy: 0.8462
# Epoch 91/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6749 - accuracy: 0.7000
# Epoch 91: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6749 - accuracy: 0.7000 - val_loss: 0.5541 - val_accuracy: 0.8462
# Epoch 92/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4939 - accuracy: 0.8750
# Epoch 92: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.4939 - accuracy: 0.8750 - val_loss: 0.5447 - val_accuracy: 0.8462
# Epoch 93/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5526 - accuracy: 0.7500
# Epoch 93: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5526 - accuracy: 0.7500 - val_loss: 0.5369 - val_accuracy: 0.8269
# Epoch 94/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5317 - accuracy: 0.7500
# Epoch 94: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5317 - accuracy: 0.7500 - val_loss: 0.5320 - val_accuracy: 0.7885
# Epoch 95/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4862 - accuracy: 0.7500
# Epoch 95: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 9s/step - loss: 0.4862 - accuracy: 0.7500 - val_loss: 0.5157 - val_accuracy: 0.8269
# Epoch 96/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4194 - accuracy: 0.9000
# Epoch 96: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.4194 - accuracy: 0.9000 - val_loss: 0.4954 - val_accuracy: 0.9038
# Epoch 97/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5452 - accuracy: 0.7500
# Epoch 97: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.5452 - accuracy: 0.7500 - val_loss: 0.4759 - val_accuracy: 0.9231
# Epoch 98/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5877 - accuracy: 0.7000
# Epoch 98: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5877 - accuracy: 0.7000 - val_loss: 0.4677 - val_accuracy: 0.8654
# Epoch 99/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5672 - accuracy: 0.7000
# Epoch 99: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.5672 - accuracy: 0.7000 - val_loss: 0.4667 - val_accuracy: 0.8077
# Epoch 100/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2986 - accuracy: 0.9000
# Epoch 100: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.2986 - accuracy: 0.9000 - val_loss: 0.4277 - val_accuracy: 0.8846
# Epoch 101/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7166 - accuracy: 0.5500
# Epoch 101: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.7166 - accuracy: 0.5500 - val_loss: 0.4175 - val_accuracy: 0.9231
# Epoch 102/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5129 - accuracy: 0.7500
# Epoch 102: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.5129 - accuracy: 0.7500 - val_loss: 0.4258 - val_accuracy: 0.9038
# Epoch 103/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3446 - accuracy: 0.9000
# Epoch 103: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.3446 - accuracy: 0.9000 - val_loss: 0.4339 - val_accuracy: 0.8462
# Epoch 104/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5668 - accuracy: 0.7500
# Epoch 104: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5668 - accuracy: 0.7500 - val_loss: 0.4232 - val_accuracy: 0.9038
# Epoch 105/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5242 - accuracy: 0.7000
# Epoch 105: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.5242 - accuracy: 0.7000 - val_loss: 0.4592 - val_accuracy: 0.7885
# Epoch 106/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4209 - accuracy: 0.7500
# Epoch 106: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.4209 - accuracy: 0.7500 - val_loss: 0.5376 - val_accuracy: 0.6538
# Epoch 107/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7326 - accuracy: 0.7000
# Epoch 107: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.7326 - accuracy: 0.7000 - val_loss: 0.4815 - val_accuracy: 0.7885
# Epoch 108/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3866 - accuracy: 0.7500
# Epoch 108: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.3866 - accuracy: 0.7500 - val_loss: 0.4670 - val_accuracy: 0.8462
# Epoch 109/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5480 - accuracy: 0.6500
# Epoch 109: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.5480 - accuracy: 0.6500 - val_loss: 0.5056 - val_accuracy: 0.7308
# Epoch 110/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6765 - accuracy: 0.6000
# Epoch 110: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6765 - accuracy: 0.6000 - val_loss: 0.4793 - val_accuracy: 0.8269
# Epoch 111/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5775 - accuracy: 0.7000
# Epoch 111: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.5775 - accuracy: 0.7000 - val_loss: 0.4764 - val_accuracy: 0.9038
# Epoch 112/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4170 - accuracy: 0.9000
# Epoch 112: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.4170 - accuracy: 0.9000 - val_loss: 0.4848 - val_accuracy: 0.8462
# Epoch 113/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5703 - accuracy: 0.7000
# Epoch 113: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.5703 - accuracy: 0.7000 - val_loss: 0.4860 - val_accuracy: 0.8654
# Epoch 114/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5549 - accuracy: 0.6875
# Epoch 114: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.5549 - accuracy: 0.6875 - val_loss: 0.4815 - val_accuracy: 0.8462
# Epoch 115/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5021 - accuracy: 0.9000
# Epoch 115: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.5021 - accuracy: 0.9000 - val_loss: 0.4779 - val_accuracy: 0.8462
# Epoch 116/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5690 - accuracy: 0.7500
# Epoch 116: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5690 - accuracy: 0.7500 - val_loss: 0.4751 - val_accuracy: 0.8846
# Epoch 117/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3817 - accuracy: 0.8000
# Epoch 117: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.3817 - accuracy: 0.8000 - val_loss: 0.4879 - val_accuracy: 0.8269
# Epoch 118/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5955 - accuracy: 0.7500
# Epoch 118: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5955 - accuracy: 0.7500 - val_loss: 0.5036 - val_accuracy: 0.7500
# Epoch 119/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6408 - accuracy: 0.7000
# Epoch 119: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.6408 - accuracy: 0.7000 - val_loss: 0.4958 - val_accuracy: 0.7885
# Epoch 120/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5812 - accuracy: 0.7500
# Epoch 120: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.5812 - accuracy: 0.7500 - val_loss: 0.4751 - val_accuracy: 0.8654
# Epoch 121/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6065 - accuracy: 0.7000
# Epoch 121: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.6065 - accuracy: 0.7000 - val_loss: 0.4662 - val_accuracy: 0.8654
# Epoch 122/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5175 - accuracy: 0.7500
# Epoch 122: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5175 - accuracy: 0.7500 - val_loss: 0.5014 - val_accuracy: 0.7500
# Epoch 123/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5544 - accuracy: 0.5500
# Epoch 123: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5544 - accuracy: 0.5500 - val_loss: 0.5602 - val_accuracy: 0.6538
# Epoch 124/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5873 - accuracy: 0.6500
# Epoch 124: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5873 - accuracy: 0.6500 - val_loss: 0.5311 - val_accuracy: 0.7115
# Epoch 125/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6415 - accuracy: 0.6500
# Epoch 125: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.6415 - accuracy: 0.6500 - val_loss: 0.4911 - val_accuracy: 0.8077
# Epoch 126/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6728 - accuracy: 0.5000
# Epoch 126: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.6728 - accuracy: 0.5000 - val_loss: 0.4682 - val_accuracy: 0.9038
# Epoch 127/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4431 - accuracy: 0.9000
# Epoch 127: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.4431 - accuracy: 0.9000 - val_loss: 0.4844 - val_accuracy: 0.8269
# Epoch 128/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6934 - accuracy: 0.6875
# Epoch 128: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.6934 - accuracy: 0.6875 - val_loss: 0.4972 - val_accuracy: 0.8077
# Epoch 129/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5500 - accuracy: 0.7000
# Epoch 129: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5500 - accuracy: 0.7000 - val_loss: 0.4922 - val_accuracy: 0.8269
# Epoch 130/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4654 - accuracy: 0.8000
# Epoch 130: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.4654 - accuracy: 0.8000 - val_loss: 0.4880 - val_accuracy: 0.8269
# Epoch 131/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6285 - accuracy: 0.7000
# Epoch 131: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.6285 - accuracy: 0.7000 - val_loss: 0.4768 - val_accuracy: 0.9038
# Epoch 132/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4621 - accuracy: 0.8000
# Epoch 132: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.4621 - accuracy: 0.8000 - val_loss: 0.4877 - val_accuracy: 0.7885
# Epoch 133/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5014 - accuracy: 0.6500
# Epoch 133: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.5014 - accuracy: 0.6500 - val_loss: 0.5088 - val_accuracy: 0.7500
# Epoch 134/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5392 - accuracy: 0.7500
# Epoch 134: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5392 - accuracy: 0.7500 - val_loss: 0.5082 - val_accuracy: 0.7500
# Epoch 135/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5220 - accuracy: 0.7000
# Epoch 135: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.5220 - accuracy: 0.7000 - val_loss: 0.4826 - val_accuracy: 0.8077
# Epoch 136/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4983 - accuracy: 0.6875
# Epoch 136: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.4983 - accuracy: 0.6875 - val_loss: 0.4659 - val_accuracy: 0.8846
# Epoch 137/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4763 - accuracy: 0.8500
# Epoch 137: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.4763 - accuracy: 0.8500 - val_loss: 0.4601 - val_accuracy: 0.9038
# Epoch 138/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4892 - accuracy: 0.7500
# Epoch 138: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.4892 - accuracy: 0.7500 - val_loss: 0.4546 - val_accuracy: 0.9038
# Epoch 139/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5724 - accuracy: 0.6500
# Epoch 139: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.5724 - accuracy: 0.6500 - val_loss: 0.4559 - val_accuracy: 0.8846
# Epoch 140/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4861 - accuracy: 0.8000
# Epoch 140: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.4861 - accuracy: 0.8000 - val_loss: 0.4619 - val_accuracy: 0.8077
# Epoch 141/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4289 - accuracy: 0.8000
# Epoch 141: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.4289 - accuracy: 0.8000 - val_loss: 0.4424 - val_accuracy: 0.9038
# Epoch 142/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4607 - accuracy: 0.8500
# Epoch 142: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.4607 - accuracy: 0.8500 - val_loss: 0.4271 - val_accuracy: 0.9038
# Epoch 143/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4396 - accuracy: 0.7500
# Epoch 143: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.4396 - accuracy: 0.7500 - val_loss: 0.4194 - val_accuracy: 0.9231
# Epoch 144/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6774 - accuracy: 0.6500
# Epoch 144: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.6774 - accuracy: 0.6500 - val_loss: 0.4321 - val_accuracy: 0.8846
# Epoch 145/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3703 - accuracy: 0.9000
# Epoch 145: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.3703 - accuracy: 0.9000 - val_loss: 0.4682 - val_accuracy: 0.7500
# Epoch 146/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7392 - accuracy: 0.6000
# Epoch 146: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.7392 - accuracy: 0.6000 - val_loss: 0.4548 - val_accuracy: 0.7885
# Epoch 147/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4184 - accuracy: 0.8000
# Epoch 147: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.4184 - accuracy: 0.8000 - val_loss: 0.4370 - val_accuracy: 0.8846
# Epoch 148/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4055 - accuracy: 0.8000
# Epoch 148: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.4055 - accuracy: 0.8000 - val_loss: 0.4255 - val_accuracy: 0.9038
# Epoch 149/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4479 - accuracy: 0.8000
# Epoch 149: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.4479 - accuracy: 0.8000 - val_loss: 0.4089 - val_accuracy: 0.9038
# Epoch 150/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5274 - accuracy: 0.7000
# Epoch 150: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5274 - accuracy: 0.7000 - val_loss: 0.4054 - val_accuracy: 0.9038
# Epoch 151/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7944 - accuracy: 0.5000
# Epoch 151: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.7944 - accuracy: 0.5000 - val_loss: 0.4086 - val_accuracy: 0.9038
# Epoch 152/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5090 - accuracy: 0.6500
# Epoch 152: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5090 - accuracy: 0.6500 - val_loss: 0.4956 - val_accuracy: 0.7308
# Epoch 153/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4413 - accuracy: 0.8500
# Epoch 153: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.4413 - accuracy: 0.8500 - val_loss: 0.5916 - val_accuracy: 0.6154
# Epoch 154/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4667 - accuracy: 0.7000
# Epoch 154: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.4667 - accuracy: 0.7000 - val_loss: 0.6057 - val_accuracy: 0.5962
# Epoch 155/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7699 - accuracy: 0.6000
# Epoch 155: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.7699 - accuracy: 0.6000 - val_loss: 0.5015 - val_accuracy: 0.7115
# Epoch 156/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7193 - accuracy: 0.6500
# Epoch 156: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.7193 - accuracy: 0.6500 - val_loss: 0.4350 - val_accuracy: 0.9038
# Epoch 157/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4705 - accuracy: 0.7000
# Epoch 157: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.4705 - accuracy: 0.7000 - val_loss: 0.4803 - val_accuracy: 0.7308
# Epoch 158/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4596 - accuracy: 0.8000
# Epoch 158: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.4596 - accuracy: 0.8000 - val_loss: 0.5152 - val_accuracy: 0.6346
# Epoch 159/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5856 - accuracy: 0.7500
# Epoch 159: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.5856 - accuracy: 0.7500 - val_loss: 0.5185 - val_accuracy: 0.6346
# Epoch 160/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2798 - accuracy: 0.8750
# Epoch 160: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.2798 - accuracy: 0.8750 - val_loss: 0.5054 - val_accuracy: 0.6731
# Epoch 161/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5554 - accuracy: 0.7500
# Epoch 161: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5554 - accuracy: 0.7500 - val_loss: 0.4902 - val_accuracy: 0.7500
# Epoch 162/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5609 - accuracy: 0.7500
# Epoch 162: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.5609 - accuracy: 0.7500 - val_loss: 0.4821 - val_accuracy: 0.8654
# Epoch 163/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5803 - accuracy: 0.7000
# Epoch 163: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5803 - accuracy: 0.7000 - val_loss: 0.4837 - val_accuracy: 0.8846
# Epoch 164/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4930 - accuracy: 0.8500
# Epoch 164: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.4930 - accuracy: 0.8500 - val_loss: 0.4855 - val_accuracy: 0.9038
# Epoch 165/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5699 - accuracy: 0.7000
# Epoch 165: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.5699 - accuracy: 0.7000 - val_loss: 0.4865 - val_accuracy: 0.9231
# Epoch 166/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5297 - accuracy: 0.7000
# Epoch 166: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.5297 - accuracy: 0.7000 - val_loss: 0.4854 - val_accuracy: 0.9038
# Epoch 167/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5398 - accuracy: 0.8000
# Epoch 167: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.5398 - accuracy: 0.8000 - val_loss: 0.4806 - val_accuracy: 0.8846
# Epoch 168/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4159 - accuracy: 0.9000
# Epoch 168: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.4159 - accuracy: 0.9000 - val_loss: 0.4709 - val_accuracy: 0.8846
# Epoch 169/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3355 - accuracy: 0.9000
# Epoch 169: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.3355 - accuracy: 0.9000 - val_loss: 0.4561 - val_accuracy: 0.8846
# Epoch 170/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4422 - accuracy: 0.7500
# Epoch 170: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.4422 - accuracy: 0.7500 - val_loss: 0.4424 - val_accuracy: 0.8846
# Epoch 171/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2966 - accuracy: 0.9500
# Epoch 171: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.2966 - accuracy: 0.9500 - val_loss: 0.4353 - val_accuracy: 0.8269
# Epoch 172/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4370 - accuracy: 0.8125
# Epoch 172: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.4370 - accuracy: 0.8125 - val_loss: 0.4411 - val_accuracy: 0.8077
# Epoch 173/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3244 - accuracy: 0.8500
# Epoch 173: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.3244 - accuracy: 0.8500 - val_loss: 0.4466 - val_accuracy: 0.8269
# Epoch 174/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5146 - accuracy: 0.8000
# Epoch 174: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.5146 - accuracy: 0.8000 - val_loss: 0.4180 - val_accuracy: 0.8077
# Epoch 175/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4353 - accuracy: 0.8125
# Epoch 175: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.4353 - accuracy: 0.8125 - val_loss: 0.3886 - val_accuracy: 0.8077
# Epoch 176/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4199 - accuracy: 0.7500
# Epoch 176: saving model to best_weights.hdf5
# ...
# Epoch 443/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0351 - accuracy: 1.0000
# Epoch 443: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0351 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9423
# Epoch 444/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0334 - accuracy: 1.0000
# Epoch 444: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.0334 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9423
# Epoch 445/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0681 - accuracy: 1.0000
# Epoch 445: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0681 - accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9423
# Epoch 446/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0365 - accuracy: 1.0000
# Epoch 446: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0365 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9423
# Epoch 447/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0536 - accuracy: 1.0000
# Epoch 447: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.0536 - accuracy: 1.0000 - val_loss: 0.1591 - val_accuracy: 0.9423
# Epoch 448/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0611 - accuracy: 1.0000
# Epoch 448: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0611 - accuracy: 1.0000 - val_loss: 0.1818 - val_accuracy: 0.9423
# Epoch 449/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1296 - accuracy: 0.9500
# Epoch 449: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.1296 - accuracy: 0.9500 - val_loss: 0.1859 - val_accuracy: 0.9423
# Epoch 450/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0346 - accuracy: 1.0000
# Epoch 450: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0346 - accuracy: 1.0000 - val_loss: 0.1855 - val_accuracy: 0.9423
# Epoch 451/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0220 - accuracy: 1.0000
# Epoch 451: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.1828 - val_accuracy: 0.9423
# Epoch 452/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0125 - accuracy: 1.0000
# Epoch 452: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.1814 - val_accuracy: 0.9423
# Epoch 453/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0494 - accuracy: 1.0000
# Epoch 453: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.0494 - accuracy: 1.0000 - val_loss: 0.1754 - val_accuracy: 0.9423
# Epoch 454/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0177 - accuracy: 1.0000
# Epoch 454: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.1717 - val_accuracy: 0.9423
# Epoch 455/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0365 - accuracy: 1.0000
# Epoch 455: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.0365 - accuracy: 1.0000 - val_loss: 0.1664 - val_accuracy: 0.9423
# Epoch 456/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0342 - accuracy: 1.0000
# Epoch 456: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0342 - accuracy: 1.0000 - val_loss: 0.1693 - val_accuracy: 0.9423
# Epoch 457/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0210 - accuracy: 1.0000
# Epoch 457: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.0210 - accuracy: 1.0000 - val_loss: 0.1774 - val_accuracy: 0.9423
# Epoch 458/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0186 - accuracy: 1.0000
# Epoch 458: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.1875 - val_accuracy: 0.9423
# Epoch 459/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0121 - accuracy: 1.0000
# Epoch 459: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.2004 - val_accuracy: 0.9423
# Epoch 460/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 460: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9423
# Epoch 461/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1470 - accuracy: 0.9500
# Epoch 461: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.1470 - accuracy: 0.9500 - val_loss: 0.1934 - val_accuracy: 0.9423
# Epoch 462/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 462: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.1649 - val_accuracy: 0.9615
# Epoch 463/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1271 - accuracy: 0.9000
# Epoch 463: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.1271 - accuracy: 0.9000 - val_loss: 0.1521 - val_accuracy: 0.9615
# Epoch 464/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0184 - accuracy: 1.0000
# Epoch 464: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9615
# Epoch 465/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0429 - accuracy: 1.0000
# Epoch 465: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0429 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9615
# Epoch 466/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0490 - accuracy: 1.0000
# Epoch 466: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0490 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9615
# Epoch 467/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0593 - accuracy: 1.0000
# Epoch 467: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 8s/step - loss: 0.0593 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.9615
# Epoch 468/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0327 - accuracy: 1.0000
# Epoch 468: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0327 - accuracy: 1.0000 - val_loss: 0.1766 - val_accuracy: 0.9423
# Epoch 469/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0200 - accuracy: 1.0000
# Epoch 469: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.1996 - val_accuracy: 0.9423
# Epoch 470/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1217 - accuracy: 0.9500
# Epoch 470: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.1217 - accuracy: 0.9500 - val_loss: 0.1801 - val_accuracy: 0.9423
# Epoch 471/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0295 - accuracy: 1.0000
# Epoch 471: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.0295 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.9615
# Epoch 472/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9500
# Epoch 472: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0617 - accuracy: 0.9500 - val_loss: 0.1299 - val_accuracy: 0.9615
# Epoch 473/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0549 - accuracy: 1.0000
# Epoch 473: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0549 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9615
# Epoch 474/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1391 - accuracy: 0.9500
# Epoch 474: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.1391 - accuracy: 0.9500 - val_loss: 0.1619 - val_accuracy: 0.9423
# Epoch 475/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 475: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.2035 - val_accuracy: 0.9423
# Epoch 476/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1153 - accuracy: 0.9500
# Epoch 476: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.1153 - accuracy: 0.9500 - val_loss: 0.2165 - val_accuracy: 0.9423
# Epoch 477/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0274 - accuracy: 1.0000
# Epoch 477: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0274 - accuracy: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.9423
# Epoch 478/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0377 - accuracy: 1.0000
# Epoch 478: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.0377 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9423
# Epoch 479/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0429 - accuracy: 1.0000
# Epoch 479: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0429 - accuracy: 1.0000 - val_loss: 0.1619 - val_accuracy: 0.9423
# Epoch 480/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 480: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9615
# Epoch 481/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1235 - accuracy: 0.9375
# Epoch 481: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.1235 - accuracy: 0.9375 - val_loss: 0.1706 - val_accuracy: 0.9423
# Epoch 482/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0130 - accuracy: 1.0000
# Epoch 482: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.1929 - val_accuracy: 0.9423
# Epoch 483/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0176 - accuracy: 1.0000
# Epoch 483: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9423
# Epoch 484/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0180 - accuracy: 1.0000
# Epoch 484: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.2268 - val_accuracy: 0.9423
# Epoch 485/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1103 - accuracy: 0.9500
# Epoch 485: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 4s/step - loss: 0.1103 - accuracy: 0.9500 - val_loss: 0.2030 - val_accuracy: 0.9423
# Epoch 486/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0197 - accuracy: 1.0000
# Epoch 486: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.1814 - val_accuracy: 0.9423
# Epoch 487/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0239 - accuracy: 1.0000
# Epoch 487: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.9615
# Epoch 488/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0313 - accuracy: 1.0000
# Epoch 488: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 0.1634 - val_accuracy: 0.9615
# Epoch 489/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0390 - accuracy: 1.0000
# Epoch 489: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0390 - accuracy: 1.0000 - val_loss: 0.1566 - val_accuracy: 0.9615
# Epoch 490/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0141 - accuracy: 1.0000
# Epoch 490: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9615
# Epoch 491/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0359 - accuracy: 1.0000
# Epoch 491: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 4s/step - loss: 0.0359 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9615
# Epoch 492/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0992 - accuracy: 0.9500
# Epoch 492: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0992 - accuracy: 0.9500 - val_loss: 0.1846 - val_accuracy: 0.9615
# Epoch 493/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1052 - accuracy: 0.9500
# Epoch 493: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.1052 - accuracy: 0.9500 - val_loss: 0.2585 - val_accuracy: 0.9423
# Epoch 494/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 494: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.3322 - val_accuracy: 0.9423
# Epoch 495/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0686 - accuracy: 0.9500
# Epoch 495: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0686 - accuracy: 0.9500 - val_loss: 0.3986 - val_accuracy: 0.9231
# Epoch 496/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1376 - accuracy: 0.9500
# Epoch 496: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.1376 - accuracy: 0.9500 - val_loss: 0.3105 - val_accuracy: 0.9423
# Epoch 497/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2278 - accuracy: 0.8000
# Epoch 497: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.2278 - accuracy: 0.8000 - val_loss: 0.1583 - val_accuracy: 0.9615
# Epoch 498/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0543 - accuracy: 1.0000
# Epoch 498: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.0543 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.9808
# Epoch 499/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2355 - accuracy: 0.9000
# Epoch 499: saving model to best_weights.hdf5
# 1/1 [==============================] - 1s 2s/step - loss: 0.2355 - accuracy: 0.9000 - val_loss: 0.1602 - val_accuracy: 0.9808
# Epoch 500/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1650 - accuracy: 0.9500
# Epoch 500: saving model to best_weights.hdf5
# 1/1 [==============================] - 2s 3s/step - loss: 0.1650 - accuracy: 0.9500 - val_loss: 0.1074 - val_accuracy: 0.9615

# %%
model4.save_weights("model_weights_hist.h5")
model4.save("model_hist.h5")

# %% [markdown]
# ##Display variation of each epoch in training accuracy and loss function

# %%
# Extract the training history
training_loss = history.history['loss']
training_accuracy = history.history['accuracy']
validation_loss = history.history['val_loss']
validation_accuracy = history.history['val_accuracy']

# Create a figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(9, 5))

# Plot the training and validation loss
axs[0].plot(range(1, N_epochs + 1), training_loss, label='Training Loss', color='cyan')
axs[0].plot(range(1, N_epochs + 1), validation_loss, label='Validation Loss', color='purple')
axs[0].set_title('Training and Validation Loss')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')
axs[0].legend()

# Plot the training and validation accuracy
axs[1].plot(range(1, N_epochs + 1), training_accuracy, label='Training Accuracy', color='cyan')
axs[1].plot(range(1, N_epochs + 1), validation_accuracy, label='Validation Accuracy', color='purple')
axs[1].set_title('Training and Validation Accuracy')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Accuracy')
axs[1].legend()

# Adjust the spacing between subplots
plt.tight_layout()
# Show the figure
plt.show()

# %% [markdown]
# ##Display model4 performance metrics

# %%
# Convert true labels to binary format
y_test_binary = np.argmax(y_test, axis=1)

# Evaluate the model on the test set
test_loss, test_accuracy = model4.evaluate(x_test, y_test, verbose=0)

# Predict the labels for the test set
y_pred_classes = np.argmax(model4.predict(x_test), axis=1)

# Compute model performance metrics
classification_rep = classification_report(y_test_binary, y_pred_classes)
confusion_mat = confusion_matrix(y_test_binary, y_pred_classes)
true_negative, false_positive, _, _ = confusion_mat.ravel()
specificity = true_negative / (true_negative + false_positive)

# Print model performance metrics
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Classification Report:")
print(classification_rep)
print("Confusion Matrix:")
print(confusion_mat)
print("Test Specificity:", specificity)

# Define the class labels
class_labels = ['Normal', 'Abnormal']

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(6, 6))
sns.heatmap(confusion_mat, annot=True, cmap='Blues', fmt='d', xticklabels=class_labels, yticklabels=class_labels)
ax.set_xlabel('Predicted Labels')
ax.set_ylabel('True Labels')
ax.set_title('Confusion Matrix')
plt.show()
# Out:
# 2/2 [==============================] - 0s 55ms/step
# Test Loss: 0.038450367748737335
# Test Accuracy: 0.9807692170143127
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        26
#            1       0.96      1.00      0.98        26
#
#     accuracy                           0.98        52
#    macro avg       0.98      0.98      0.98        52
# weighted avg       0.98      0.98      0.98        52
#
# Confusion Matrix:
# [[25  1]
#  [ 0 26]]
# Test Specificity: 0.9615384615384616
