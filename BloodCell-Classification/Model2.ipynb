# %% [markdown]
# ##Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/IP/HW3/dataset
import cv2
import cv2 as cv
import numpy as np
import os
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
import keras.utils as image
import random
import math
import shutil
import pathlib
from pathlib import Path
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
from sklearn.metrics import confusion_matrix,precision_score,recall_score,ConfusionMatrixDisplay,roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn import metrics
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from keras.utils import np_utils
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Dense,Flatten,Activation
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Activation, Dropout, Conv2D, ZeroPadding2D,MaxPooling2D,Input
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
from tensorflow.keras.optimizers import Adam,SGD
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/IP/HW3/dataset
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
data = []
images_dir = '/content/drive/MyDrive/IP/HW3/dataset'
for filename in os.listdir(images_dir):
    if filename.endswith(".tif"):
        img_path = os.path.join(images_dir, filename)
        img_id = filename.split('_')[0][2:]
        label = int(filename.split('_')[1].split('.')[0])
        data.append((img_path, label))

D_F = pd.DataFrame(data, columns=['image', 'label'])
print(D_F)
# Out:
#                                                  image  label
# 0    /content/drive/MyDrive/IP/HW3/dataset/Im134_0.tif      0
# 1    /content/drive/MyDrive/IP/HW3/dataset/Im132_0.tif      0
# 2    /content/drive/MyDrive/IP/HW3/dataset/Im131_0.tif      0
# 3    /content/drive/MyDrive/IP/HW3/dataset/Im136_0.tif      0
# 4    /content/drive/MyDrive/IP/HW3/dataset/Im133_0.tif      0
# ..                                                 ...    ...
# 255  /content/drive/MyDrive/IP/HW3/dataset/Im126_1.tif      1
# 256  /content/drive/MyDrive/IP/HW3/dataset/Im128_1.tif      1
# 257  /content/drive/MyDrive/IP/HW3/dataset/Im124_1.tif      1
# 258  /content/drive/MyDrive/IP/HW3/dataset/Im130_1.tif      1
# 259  /content/drive/MyDrive/IP/HW3/dataset/Im122_1.tif      1
#
# [260 rows x 2 columns]

# %%
def data_preprocessing(dataframe, dim):
    n = dataframe.shape[0]
    images = np.zeros((n, dim, dim, 3), dtype=np.float32)
    labels = np.zeros((n, 2), dtype=np.float32)

    for i, (_, row) in enumerate(dataframe.iterrows()):
        img = cv2.imread(str(row['image']))
        img = cv2.resize(img, (dim, dim))
        encoded_label = np_utils.to_categorical(row['label'], num_classes=2)
        orig_img = img.astype(np.float32) / 255.
        images[i] = orig_img
        labels[i] = encoded_label

    return images, labels

dim = 257
images, labels = data_preprocessing(D_F, dim)
print(f'Images shape: {images.shape}')
print(f'Labels shape: {labels.shape}')
# Out:
# Images shape: (260, 257, 257, 3)
# Labels shape: (260, 2)

# %% [markdown]
# ##Seperate 60% of the dataset for training , 20% for test and 20% for validation

# %%
seed = 369
np.random.seed(seed)

# %%
# Splitting the data into train, validation, and test sets
train_ratio = 0.6
val_ratio = 0.2
test_ratio = 0.2

x , y = images, labels

x_train_val, x_test, y_train_val, y_test = train_test_split(x, y, test_size=test_ratio, stratify=y, random_state=seed)
x_train, x_val, y_train, y_val = train_test_split(x_train_val, y_train_val, test_size=val_ratio/(train_ratio+val_ratio),
                                                  stratify=y_train_val, random_state=seed)

# Printing the shapes of the train, validation, and test sets
print(f"X_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_val shape: {x_val.shape}")
print(f"y_val shape: {y_val.shape}")
print(f"X_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (156, 257, 257, 3)
# y_train shape: (156, 2)
# X_val shape: (52, 257, 257, 3)
# y_val shape: (52, 2)
# X_test shape: (52, 257, 257, 3)
# y_test shape: (52, 2)

# %% [markdown]
# ##Create artificial images with data augmentation and add them to our dataset

# %%
Batch_S = 100
N_epochs = 500
LR = 0.0001

# %%
# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

training_data = datagen.flow(x_train, y_train, batch_size=10)

num_train_samples = x_train.shape[0]
total_augmented_images = num_train_samples * 10

print("Total augmented images per original image:", total_augmented_images)
# Out:
# Total augmented images per original image: 1560

# %%
# Number of images in the train, validation, and test sets
print("Train set:")
print("Number of images:", x_train.shape[0])

print("Validation set:")
print("Number of images:", x_val.shape[0])

print("Test set:")
print("Number of images:", x_test.shape[0])

# Total number of augmented images
num_train_samples = x_train.shape[0]
batch_size = Batch_S
total_augmented_images = num_train_samples * 10

print("Total augmented images after augmentation:", total_augmented_images)

# Total number of images after augmentation
total_images = total_augmented_images + x_train.shape[0] + x_val.shape[0] +  x_test.shape[0]
print("Total images after augmentation:", total_images)
# Out:
# Train set:
# Number of images: 156
# Validation set:
# Number of images: 52
# Test set:
# Number of images: 52
# Total augmented images after augmentation: 1560
# Total images after augmentation: 1820

# %% [markdown]
# ##Create a convolutional neural network (CNN2)

# %%
model2 = Sequential()

# Convolutional layers
model2.add(Input(shape=(257, 257, 3)))

model2.add(Conv2D(64, (3, 3), strides=(1, 1), padding='same'))
model2.add(Activation('relu'))
model2.add(Conv2D(64, (3, 3), strides=(1, 1), padding='same'))
model2.add(Activation('relu'))
model2.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model2.add(Conv2D(128, (3, 3), strides=(1, 1), padding='same'))
model2.add(Activation('relu'))
model2.add(Conv2D(128, (3, 3), strides=(1, 1), padding='same'))
model2.add(Activation('relu'))
model2.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model2.add(Conv2D(256, (3, 3), strides=(1, 1), padding='same'))
model2.add(Activation('relu'))
model2.add(Conv2D(256, (3, 3), strides=(1, 1), padding='same'))
model2.add(Activation('relu'))
model2.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

# Fully connected layers
model2.add(Flatten())
model2.add(Dense(512))
model2.add(Activation('relu'))
model2.add(Dropout(0.5))

model2.add(Dense(256))
model2.add(Activation('relu'))
model2.add(Dropout(0.5))

model2.add(Dense(2))
model2.add(Activation('softmax'))

model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 257, 257, 64)      1792
#
#  activation (Activation)     (None, 257, 257, 64)      0
#
#  conv2d_1 (Conv2D)           (None, 257, 257, 64)      36928
#
#  activation_1 (Activation)   (None, 257, 257, 64)      0
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 64)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 128)     73856
#
#  activation_2 (Activation)   (None, 128, 128, 128)     0
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 128)     147584
#
#  activation_3 (Activation)   (None, 128, 128, 128)     0
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 256)       295168
#
#  activation_4 (Activation)   (None, 64, 64, 256)       0
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 256)       590080
#
#  activation_5 (Activation)   (None, 64, 64, 256)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 262144)            0
#
#  dense (Dense)               (None, 512)               134218240
#
#  activation_6 (Activation)   (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  activation_7 (Activation)   (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 2)                 514
#
#  activation_8 (Activation)   (None, 2)                 0
#
# =================================================================
# Total params: 135,495,490
# Trainable params: 135,495,490
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model2, show_shapes=True)

# %% [markdown]
# ##Training the model2

# %%
optimizer = Adam(learning_rate=LR)
model2.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath="best_weights.hdf5", monitor = 'val_accuracy',verbose=1, save_weights_only=True)

# %%
history = model2.fit(
    training_data,
    epochs= N_epochs,
    validation_data= (x_val, y_val),
    steps_per_epoch= x_train.shape[0] / Batch_S,
    verbose=1,
    callbacks=[checkpointer])
# Out:
# Epoch 1/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7029 - accuracy: 0.6000
# Epoch 1: saving model to best_weights.hdf5
# 1/1 [==============================] - 31s 23s/step - loss: 0.7029 - accuracy: 0.6000 - val_loss: 0.6944 - val_accuracy: 0.5000
# Epoch 2/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7406 - accuracy: 0.4000
# Epoch 2: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.7406 - accuracy: 0.4000 - val_loss: 0.6941 - val_accuracy: 0.5000
# Epoch 3/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6978 - accuracy: 0.4500
# Epoch 3: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.6978 - accuracy: 0.4500 - val_loss: 0.6921 - val_accuracy: 0.5000
# Epoch 4/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6895 - accuracy: 0.4500
# Epoch 4: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6895 - accuracy: 0.4500 - val_loss: 0.6928 - val_accuracy: 0.5000
# Epoch 5/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6750 - accuracy: 0.6500
# Epoch 5: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 9s/step - loss: 0.6750 - accuracy: 0.6500 - val_loss: 0.6946 - val_accuracy: 0.5000
# Epoch 6/500
# 2/1 [======================================] - ETA: -1s - loss: 0.7111 - accuracy: 0.4375
# Epoch 6: saving model to best_weights.hdf5
# 1/1 [==============================] - 6s 11s/step - loss: 0.7111 - accuracy: 0.4375 - val_loss: 0.6938 - val_accuracy: 0.5000
# Epoch 7/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6706 - accuracy: 0.6875
# Epoch 7: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.6706 - accuracy: 0.6875 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 8/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7002 - accuracy: 0.5625
# Epoch 8: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 9s/step - loss: 0.7002 - accuracy: 0.5625 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 9/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7070 - accuracy: 0.3000
# Epoch 9: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.7070 - accuracy: 0.3000 - val_loss: 0.6929 - val_accuracy: 0.5000
# Epoch 10/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6720 - accuracy: 0.6500
# Epoch 10: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6720 - accuracy: 0.6500 - val_loss: 0.6922 - val_accuracy: 0.6154
# Epoch 11/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6877 - accuracy: 0.6000
# Epoch 11: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.6877 - accuracy: 0.6000 - val_loss: 0.6910 - val_accuracy: 0.5000
# Epoch 12/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5500
# Epoch 12: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.6925 - accuracy: 0.5500 - val_loss: 0.6902 - val_accuracy: 0.5000
# Epoch 13/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7016 - accuracy: 0.6000
# Epoch 13: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.7016 - accuracy: 0.6000 - val_loss: 0.6907 - val_accuracy: 0.5000
# Epoch 14/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7086 - accuracy: 0.3750
# Epoch 14: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.7086 - accuracy: 0.3750 - val_loss: 0.6913 - val_accuracy: 0.7500
# Epoch 15/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6832 - accuracy: 0.6250
# Epoch 15: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.6832 - accuracy: 0.6250 - val_loss: 0.6916 - val_accuracy: 0.5000
# Epoch 16/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6837 - accuracy: 0.6875
# Epoch 16: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.6837 - accuracy: 0.6875 - val_loss: 0.6918 - val_accuracy: 0.5000
# Epoch 17/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6983 - accuracy: 0.4500
# Epoch 17: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.6983 - accuracy: 0.4500 - val_loss: 0.6922 - val_accuracy: 0.5000
# Epoch 18/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6887 - accuracy: 0.6000
# Epoch 18: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.6887 - accuracy: 0.6000 - val_loss: 0.6909 - val_accuracy: 0.5000
# Epoch 19/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6922 - accuracy: 0.5000
# Epoch 19: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 7s/step - loss: 0.6922 - accuracy: 0.5000 - val_loss: 0.6883 - val_accuracy: 0.6731
# Epoch 20/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6837 - accuracy: 0.6500
# Epoch 20: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.6837 - accuracy: 0.6500 - val_loss: 0.6849 - val_accuracy: 0.7692
# Epoch 21/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6954 - accuracy: 0.5000
# Epoch 21: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 9s/step - loss: 0.6954 - accuracy: 0.5000 - val_loss: 0.6819 - val_accuracy: 0.6731
# Epoch 22/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6526 - accuracy: 0.7500
# Epoch 22: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6526 - accuracy: 0.7500 - val_loss: 0.6749 - val_accuracy: 0.5577
# Epoch 23/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6864 - accuracy: 0.5500
# Epoch 23: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6864 - accuracy: 0.5500 - val_loss: 0.6810 - val_accuracy: 0.5000
# Epoch 24/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7201 - accuracy: 0.4375
# Epoch 24: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 8s/step - loss: 0.7201 - accuracy: 0.4375 - val_loss: 0.6718 - val_accuracy: 0.5000
# Epoch 25/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6550 - accuracy: 0.6000
# Epoch 25: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6550 - accuracy: 0.6000 - val_loss: 0.6690 - val_accuracy: 0.5385
# Epoch 26/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7116 - accuracy: 0.5500
# Epoch 26: saving model to best_weights.hdf5
# 1/1 [==============================] - 9s 16s/step - loss: 0.7116 - accuracy: 0.5500 - val_loss: 0.6682 - val_accuracy: 0.5192
# Epoch 27/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7061 - accuracy: 0.4375
# Epoch 27: saving model to best_weights.hdf5
# 1/1 [==============================] - 9s 15s/step - loss: 0.7061 - accuracy: 0.4375 - val_loss: 0.6694 - val_accuracy: 0.5577
# Epoch 28/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6854 - accuracy: 0.6000
# Epoch 28: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.6854 - accuracy: 0.6000 - val_loss: 0.6723 - val_accuracy: 0.6538
# Epoch 29/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6687 - accuracy: 0.6500
# Epoch 29: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.6687 - accuracy: 0.6500 - val_loss: 0.6717 - val_accuracy: 0.6346
# Epoch 30/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6921 - accuracy: 0.5000
# Epoch 30: saving model to best_weights.hdf5
# 1/1 [==============================] - 9s 15s/step - loss: 0.6921 - accuracy: 0.5000 - val_loss: 0.6685 - val_accuracy: 0.5385
# Epoch 31/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6446 - accuracy: 0.7000
# Epoch 31: saving model to best_weights.hdf5
# 1/1 [==============================] - 8s 13s/step - loss: 0.6446 - accuracy: 0.7000 - val_loss: 0.6607 - val_accuracy: 0.5000
# Epoch 32/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6594 - accuracy: 0.5000
# Epoch 32: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.6594 - accuracy: 0.5000 - val_loss: 0.6668 - val_accuracy: 0.5000
# Epoch 33/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7352 - accuracy: 0.4000
# Epoch 33: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.7352 - accuracy: 0.4000 - val_loss: 0.6600 - val_accuracy: 0.5000
# Epoch 34/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6695 - accuracy: 0.3500
# Epoch 34: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.6695 - accuracy: 0.3500 - val_loss: 0.6671 - val_accuracy: 0.5385
# Epoch 35/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6565 - accuracy: 0.7000
# Epoch 35: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 9s/step - loss: 0.6565 - accuracy: 0.7000 - val_loss: 0.6663 - val_accuracy: 0.5769
# Epoch 36/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6632 - accuracy: 0.6500
# Epoch 36: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.6632 - accuracy: 0.6500 - val_loss: 0.6614 - val_accuracy: 0.5769
# Epoch 37/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6402 - accuracy: 0.7000
# Epoch 37: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.6402 - accuracy: 0.7000 - val_loss: 0.6485 - val_accuracy: 0.5385
# Epoch 38/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5814 - accuracy: 0.8125
# Epoch 38: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.5814 - accuracy: 0.8125 - val_loss: 0.6553 - val_accuracy: 0.5000
# Epoch 39/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6733 - accuracy: 0.5500
# Epoch 39: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6733 - accuracy: 0.5500 - val_loss: 0.6357 - val_accuracy: 0.5000
# Epoch 40/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7142 - accuracy: 0.5000
# Epoch 40: saving model to best_weights.hdf5
# 1/1 [==============================] - 14s 24s/step - loss: 0.7142 - accuracy: 0.5000 - val_loss: 0.6334 - val_accuracy: 0.6538
# Epoch 41/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7039 - accuracy: 0.5500
# Epoch 41: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.7039 - accuracy: 0.5500 - val_loss: 0.6501 - val_accuracy: 0.7885
# Epoch 42/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6543 - accuracy: 0.8125
# Epoch 42: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.6543 - accuracy: 0.8125 - val_loss: 0.6624 - val_accuracy: 0.6923
# Epoch 43/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6440 - accuracy: 0.7500
# Epoch 43: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.6440 - accuracy: 0.7500 - val_loss: 0.6749 - val_accuracy: 0.5000
# Epoch 44/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6511 - accuracy: 0.6500
# Epoch 44: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6511 - accuracy: 0.6500 - val_loss: 0.6996 - val_accuracy: 0.5000
# Epoch 45/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6389 - accuracy: 0.5500
# Epoch 45: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6389 - accuracy: 0.5500 - val_loss: 0.7177 - val_accuracy: 0.5000
# Epoch 46/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6764 - accuracy: 0.6000
# Epoch 46: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6764 - accuracy: 0.6000 - val_loss: 0.7187 - val_accuracy: 0.5000
# Epoch 47/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6460 - accuracy: 0.6000
# Epoch 47: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6460 - accuracy: 0.6000 - val_loss: 0.6734 - val_accuracy: 0.5000
# Epoch 48/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6359 - accuracy: 0.6000
# Epoch 48: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6359 - accuracy: 0.6000 - val_loss: 0.6247 - val_accuracy: 0.7692
# Epoch 49/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6056 - accuracy: 0.7000
# Epoch 49: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6056 - accuracy: 0.7000 - val_loss: 0.6065 - val_accuracy: 0.6346
# Epoch 50/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6133 - accuracy: 0.7500
# Epoch 50: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6133 - accuracy: 0.7500 - val_loss: 0.6257 - val_accuracy: 0.6154
# Epoch 51/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6392 - accuracy: 0.6000
# Epoch 51: saving model to best_weights.hdf5
# 1/1 [==============================] - 14s 24s/step - loss: 0.6392 - accuracy: 0.6000 - val_loss: 0.6271 - val_accuracy: 0.6154
# Epoch 52/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5275 - accuracy: 0.8500
# Epoch 52: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.5275 - accuracy: 0.8500 - val_loss: 0.6147 - val_accuracy: 0.6346
# Epoch 53/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6673 - accuracy: 0.7000
# Epoch 53: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.6673 - accuracy: 0.7000 - val_loss: 0.5844 - val_accuracy: 0.6538
# Epoch 54/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5859 - accuracy: 0.7500
# Epoch 54: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.5859 - accuracy: 0.7500 - val_loss: 0.5662 - val_accuracy: 0.6731
# Epoch 55/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5484 - accuracy: 0.8500
# Epoch 55: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.5484 - accuracy: 0.8500 - val_loss: 0.5517 - val_accuracy: 0.7500
# Epoch 56/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5879 - accuracy: 0.7500
# Epoch 56: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.5879 - accuracy: 0.7500 - val_loss: 0.5257 - val_accuracy: 0.7308
# Epoch 57/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6250 - accuracy: 0.6250
# Epoch 57: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6250 - accuracy: 0.6250 - val_loss: 0.5051 - val_accuracy: 0.8077
# Epoch 58/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5796 - accuracy: 0.6500
# Epoch 58: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.5796 - accuracy: 0.6500 - val_loss: 0.5119 - val_accuracy: 0.7500
# Epoch 59/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6429 - accuracy: 0.7000
# Epoch 59: saving model to best_weights.hdf5
# 1/1 [==============================] - 9s 16s/step - loss: 0.6429 - accuracy: 0.7000 - val_loss: 0.5094 - val_accuracy: 0.7308
# Epoch 60/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6356 - accuracy: 0.6000
# Epoch 60: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.6356 - accuracy: 0.6000 - val_loss: 0.5451 - val_accuracy: 0.6538
# Epoch 61/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6789 - accuracy: 0.6500
# Epoch 61: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.6789 - accuracy: 0.6500 - val_loss: 0.4995 - val_accuracy: 0.7885
# Epoch 62/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6484 - accuracy: 0.7500
# Epoch 62: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.6484 - accuracy: 0.7500 - val_loss: 0.5391 - val_accuracy: 0.7885
# Epoch 63/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5435 - accuracy: 0.7500
# Epoch 63: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.5435 - accuracy: 0.7500 - val_loss: 0.5159 - val_accuracy: 0.7692
# Epoch 64/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4373 - accuracy: 0.9000
# Epoch 64: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.4373 - accuracy: 0.9000 - val_loss: 0.4995 - val_accuracy: 0.8077
# Epoch 65/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5520 - accuracy: 0.8000
# Epoch 65: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.5520 - accuracy: 0.8000 - val_loss: 0.5018 - val_accuracy: 0.7692
# Epoch 66/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6051 - accuracy: 0.7000
# Epoch 66: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6051 - accuracy: 0.7000 - val_loss: 0.4772 - val_accuracy: 0.8077
# Epoch 67/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5161 - accuracy: 0.8500
# Epoch 67: saving model to best_weights.hdf5
# 1/1 [==============================] - 8s 14s/step - loss: 0.5161 - accuracy: 0.8500 - val_loss: 0.4724 - val_accuracy: 0.7885
# Epoch 68/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6088 - accuracy: 0.8000
# Epoch 68: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.6088 - accuracy: 0.8000 - val_loss: 0.4646 - val_accuracy: 0.7692
# Epoch 69/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6203 - accuracy: 0.7500
# Epoch 69: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.6203 - accuracy: 0.7500 - val_loss: 0.4552 - val_accuracy: 0.7692
# Epoch 70/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3242 - accuracy: 1.0000
# Epoch 70: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.3242 - accuracy: 1.0000 - val_loss: 0.4413 - val_accuracy: 0.7885
# Epoch 71/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6037 - accuracy: 0.7500
# Epoch 71: saving model to best_weights.hdf5
# 1/1 [==============================] - 9s 16s/step - loss: 0.6037 - accuracy: 0.7500 - val_loss: 0.4475 - val_accuracy: 0.7692
# Epoch 72/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5876 - accuracy: 0.7000
# Epoch 72: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.5876 - accuracy: 0.7000 - val_loss: 0.4233 - val_accuracy: 0.7692
# Epoch 73/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3928 - accuracy: 0.8750
# Epoch 73: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.3928 - accuracy: 0.8750 - val_loss: 0.4923 - val_accuracy: 0.7885
# Epoch 74/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7133 - accuracy: 0.6000
# Epoch 74: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.7133 - accuracy: 0.6000 - val_loss: 0.4137 - val_accuracy: 0.7500
# Epoch 75/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4125 - accuracy: 0.8500
# Epoch 75: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.4125 - accuracy: 0.8500 - val_loss: 0.4332 - val_accuracy: 0.7885
# Epoch 76/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6550 - accuracy: 0.6500
# Epoch 76: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6550 - accuracy: 0.6500 - val_loss: 0.4169 - val_accuracy: 0.7885
# Epoch 77/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6123 - accuracy: 0.6000
# Epoch 77: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6123 - accuracy: 0.6000 - val_loss: 0.4181 - val_accuracy: 0.7692
# Epoch 78/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5305 - accuracy: 0.7500
# Epoch 78: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.5305 - accuracy: 0.7500 - val_loss: 0.4108 - val_accuracy: 0.7885
# Epoch 79/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4054 - accuracy: 0.8500
# Epoch 79: saving model to best_weights.hdf5
# 1/1 [==============================] - 9s 16s/step - loss: 0.4054 - accuracy: 0.8500 - val_loss: 0.4311 - val_accuracy: 0.8462
# Epoch 80/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4543 - accuracy: 0.8500
# Epoch 80: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.4543 - accuracy: 0.8500 - val_loss: 0.3918 - val_accuracy: 0.8077
# Epoch 81/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4643 - accuracy: 0.8000
# Epoch 81: saving model to best_weights.hdf5
# 1/1 [==============================] - 10s 17s/step - loss: 0.4643 - accuracy: 0.8000 - val_loss: 0.4598 - val_accuracy: 0.8077
# Epoch 82/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4897 - accuracy: 0.8000
# Epoch 82: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.4897 - accuracy: 0.8000 - val_loss: 0.4279 - val_accuracy: 0.7885
# Epoch 83/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4383 - accuracy: 0.7500
# Epoch 83: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.4383 - accuracy: 0.7500 - val_loss: 0.4390 - val_accuracy: 0.6923
# Epoch 84/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5161 - accuracy: 0.7500
# Epoch 84: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.5161 - accuracy: 0.7500 - val_loss: 0.4261 - val_accuracy: 0.7308
# Epoch 85/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3465 - accuracy: 0.8500
# Epoch 85: saving model to best_weights.hdf5
# 1/1 [==============================] - 9s 15s/step - loss: 0.3465 - accuracy: 0.8500 - val_loss: 0.3853 - val_accuracy: 0.7885
# Epoch 86/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5271 - accuracy: 0.7500
# Epoch 86: saving model to best_weights.hdf5
# 1/1 [==============================] - 7s 11s/step - loss: 0.5271 - accuracy: 0.7500 - val_loss: 0.3979 - val_accuracy: 0.8077
# Epoch 87/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5078 - accuracy: 0.7500
# Epoch 87: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.5078 - accuracy: 0.7500 - val_loss: 0.3518 - val_accuracy: 0.8269
# Epoch 88/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4539 - accuracy: 0.7500
# Epoch 88: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.4539 - accuracy: 0.7500 - val_loss: 0.4713 - val_accuracy: 0.7308
# Epoch 89/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4979 - accuracy: 0.7000
# Epoch 89: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.4979 - accuracy: 0.7000 - val_loss: 0.3601 - val_accuracy: 0.8846
# Epoch 90/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4008 - accuracy: 0.8500
# Epoch 90: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.4008 - accuracy: 0.8500 - val_loss: 0.4075 - val_accuracy: 0.8077
# Epoch 91/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2954 - accuracy: 0.8500
# Epoch 91: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.2954 - accuracy: 0.8500 - val_loss: 0.4981 - val_accuracy: 0.7885
# Epoch 92/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5554 - accuracy: 0.6250
# Epoch 92: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.5554 - accuracy: 0.6250 - val_loss: 0.3547 - val_accuracy: 0.7885
# Epoch 93/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3435 - accuracy: 0.8500
# Epoch 93: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.3435 - accuracy: 0.8500 - val_loss: 0.4981 - val_accuracy: 0.7692
# Epoch 94/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6767 - accuracy: 0.7000
# Epoch 94: saving model to best_weights.hdf5
# 1/1 [==============================] - 14s 24s/step - loss: 0.6767 - accuracy: 0.7000 - val_loss: 0.4996 - val_accuracy: 0.7500
# Epoch 95/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5072 - accuracy: 0.8000
# Epoch 95: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.5072 - accuracy: 0.8000 - val_loss: 0.3486 - val_accuracy: 0.8077
# Epoch 96/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4485 - accuracy: 0.8000
# Epoch 96: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.4485 - accuracy: 0.8000 - val_loss: 0.5161 - val_accuracy: 0.7500
# Epoch 97/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5981 - accuracy: 0.7500
# Epoch 97: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.5981 - accuracy: 0.7500 - val_loss: 0.5686 - val_accuracy: 0.7308
# Epoch 98/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6196 - accuracy: 0.7500
# Epoch 98: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 9s/step - loss: 0.6196 - accuracy: 0.7500 - val_loss: 0.4043 - val_accuracy: 0.8077
# Epoch 99/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3594 - accuracy: 0.8500
# Epoch 99: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.3594 - accuracy: 0.8500 - val_loss: 0.4457 - val_accuracy: 0.7115
# Epoch 100/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2350 - accuracy: 0.9000
# Epoch 100: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.2350 - accuracy: 0.9000 - val_loss: 0.6156 - val_accuracy: 0.7885
# Epoch 101/500
# 2/1 [======================================] - ETA: 0s - loss: 0.7559 - accuracy: 0.6000
# Epoch 101: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.7559 - accuracy: 0.6000 - val_loss: 0.4521 - val_accuracy: 0.8077
# Epoch 102/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5868 - accuracy: 0.7000
# Epoch 102: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.5868 - accuracy: 0.7000 - val_loss: 0.3975 - val_accuracy: 0.7885
# Epoch 103/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3333 - accuracy: 0.9500
# Epoch 103: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.3333 - accuracy: 0.9500 - val_loss: 0.4493 - val_accuracy: 0.8077
# Epoch 104/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4474 - accuracy: 0.8000
# Epoch 104: saving model to best_weights.hdf5
# 1/1 [==============================] - 13s 23s/step - loss: 0.4474 - accuracy: 0.8000 - val_loss: 0.4905 - val_accuracy: 0.8077
# Epoch 105/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6723 - accuracy: 0.6500
# Epoch 105: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.6723 - accuracy: 0.6500 - val_loss: 0.4480 - val_accuracy: 0.8269
# Epoch 106/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4940 - accuracy: 0.7500
# Epoch 106: saving model to best_weights.hdf5
# 1/1 [==============================] - 8s 14s/step - loss: 0.4940 - accuracy: 0.7500 - val_loss: 0.4416 - val_accuracy: 0.8654
# Epoch 107/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4774 - accuracy: 0.7000
# Epoch 107: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.4774 - accuracy: 0.7000 - val_loss: 0.4182 - val_accuracy: 0.9038
# Epoch 108/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4773 - accuracy: 0.8500
# Epoch 108: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.4773 - accuracy: 0.8500 - val_loss: 0.4031 - val_accuracy: 0.7692
# Epoch 109/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3762 - accuracy: 0.9000
# Epoch 109: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.3762 - accuracy: 0.9000 - val_loss: 0.3747 - val_accuracy: 0.7692
# Epoch 110/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2663 - accuracy: 0.9500
# Epoch 110: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.2663 - accuracy: 0.9500 - val_loss: 0.3535 - val_accuracy: 0.7885
# Epoch 111/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3354 - accuracy: 0.9000
# Epoch 111: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 9s/step - loss: 0.3354 - accuracy: 0.9000 - val_loss: 0.3623 - val_accuracy: 0.8077
# Epoch 112/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3560 - accuracy: 0.8500
# Epoch 112: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 9s/step - loss: 0.3560 - accuracy: 0.8500 - val_loss: 0.4428 - val_accuracy: 0.7885
# Epoch 113/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5463 - accuracy: 0.7500
# Epoch 113: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.5463 - accuracy: 0.7500 - val_loss: 0.4019 - val_accuracy: 0.7500
# Epoch 114/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2749 - accuracy: 0.8000
# Epoch 114: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.2749 - accuracy: 0.8000 - val_loss: 0.3816 - val_accuracy: 0.7692
# Epoch 115/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3268 - accuracy: 0.8000
# Epoch 115: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.3268 - accuracy: 0.8000 - val_loss: 0.3516 - val_accuracy: 0.7692
# Epoch 116/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3346 - accuracy: 0.8000
# Epoch 116: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.3346 - accuracy: 0.8000 - val_loss: 0.3066 - val_accuracy: 0.8269
# Epoch 117/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2569 - accuracy: 0.9000
# Epoch 117: saving model to best_weights.hdf5
# 1/1 [==============================] - 6s 10s/step - loss: 0.2569 - accuracy: 0.9000 - val_loss: 0.2875 - val_accuracy: 0.8654
# Epoch 118/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3491 - accuracy: 0.9000
# Epoch 118: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.3491 - accuracy: 0.9000 - val_loss: 0.3545 - val_accuracy: 0.8077
# Epoch 119/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4639 - accuracy: 0.7500
# Epoch 119: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.4639 - accuracy: 0.7500 - val_loss: 0.3877 - val_accuracy: 0.8077
# Epoch 120/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4610 - accuracy: 0.8125
# Epoch 120: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.4610 - accuracy: 0.8125 - val_loss: 0.2705 - val_accuracy: 0.8269
# Epoch 121/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2534 - accuracy: 0.9000
# Epoch 121: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.2534 - accuracy: 0.9000 - val_loss: 0.2778 - val_accuracy: 0.8846
# Epoch 122/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3449 - accuracy: 0.8500
# Epoch 122: saving model to best_weights.hdf5
# 1/1 [==============================] - 7s 12s/step - loss: 0.3449 - accuracy: 0.8500 - val_loss: 0.2623 - val_accuracy: 0.9038
# Epoch 123/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4414 - accuracy: 0.8000
# Epoch 123: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.4414 - accuracy: 0.8000 - val_loss: 0.3618 - val_accuracy: 0.8077
# Epoch 124/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4002 - accuracy: 0.8500
# Epoch 124: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.4002 - accuracy: 0.8500 - val_loss: 0.4523 - val_accuracy: 0.8077
# Epoch 125/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2924 - accuracy: 0.9000
# Epoch 125: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.2924 - accuracy: 0.9000 - val_loss: 0.2676 - val_accuracy: 0.8269
# Epoch 126/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1717 - accuracy: 0.9500
# Epoch 126: saving model to best_weights.hdf5
# 1/1 [==============================] - 9s 15s/step - loss: 0.1717 - accuracy: 0.9500 - val_loss: 0.2754 - val_accuracy: 0.9231
# Epoch 127/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2968 - accuracy: 0.9500
# Epoch 127: saving model to best_weights.hdf5
# 1/1 [==============================] - 9s 15s/step - loss: 0.2968 - accuracy: 0.9500 - val_loss: 0.2896 - val_accuracy: 0.9038
# Epoch 128/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3782 - accuracy: 0.8500
# Epoch 128: saving model to best_weights.hdf5
# 1/1 [==============================] - 6s 10s/step - loss: 0.3782 - accuracy: 0.8500 - val_loss: 0.2500 - val_accuracy: 0.9038
# Epoch 129/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4451 - accuracy: 0.7500
# Epoch 129: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.4451 - accuracy: 0.7500 - val_loss: 0.4130 - val_accuracy: 0.8077
# Epoch 130/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3899 - accuracy: 0.8500
# Epoch 130: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.3899 - accuracy: 0.8500 - val_loss: 0.5928 - val_accuracy: 0.7885
# Epoch 131/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3170 - accuracy: 0.9000
# Epoch 131: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.3170 - accuracy: 0.9000 - val_loss: 0.6737 - val_accuracy: 0.7692
# Epoch 132/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0429 - accuracy: 1.0000
# Epoch 132: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.0429 - accuracy: 1.0000 - val_loss: 0.7030 - val_accuracy: 0.7692
# Epoch 133/500
# 2/1 [======================================] - ETA: 0s - loss: 0.8692 - accuracy: 0.7500
# Epoch 133: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.8692 - accuracy: 0.7500 - val_loss: 0.5464 - val_accuracy: 0.7500
# Epoch 134/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6637 - accuracy: 0.6500
# Epoch 134: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.6637 - accuracy: 0.6500 - val_loss: 0.4162 - val_accuracy: 0.7500
# Epoch 135/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2875 - accuracy: 0.8500
# Epoch 135: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.2875 - accuracy: 0.8500 - val_loss: 0.3181 - val_accuracy: 0.8462
# Epoch 136/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1943 - accuracy: 0.9000
# Epoch 136: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.1943 - accuracy: 0.9000 - val_loss: 0.3217 - val_accuracy: 0.8269
# Epoch 137/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3587 - accuracy: 0.9500
# Epoch 137: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.3587 - accuracy: 0.9500 - val_loss: 0.3334 - val_accuracy: 0.8846
# Epoch 138/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4738 - accuracy: 0.8500
# Epoch 138: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.4738 - accuracy: 0.8500 - val_loss: 0.3413 - val_accuracy: 0.9038
# Epoch 139/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4024 - accuracy: 0.8750
# Epoch 139: saving model to best_weights.hdf5
# 1/1 [==============================] - 13s 23s/step - loss: 0.4024 - accuracy: 0.8750 - val_loss: 0.3414 - val_accuracy: 0.8846
# Epoch 140/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3115 - accuracy: 0.9000
# Epoch 140: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.3115 - accuracy: 0.9000 - val_loss: 0.3344 - val_accuracy: 0.9231
# Epoch 141/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3638 - accuracy: 0.8500
# Epoch 141: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.3638 - accuracy: 0.8500 - val_loss: 0.3302 - val_accuracy: 0.9038
# Epoch 142/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5409 - accuracy: 0.7000
# Epoch 142: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.5409 - accuracy: 0.7000 - val_loss: 0.3319 - val_accuracy: 0.7885
# Epoch 143/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4094 - accuracy: 0.7500
# Epoch 143: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.4094 - accuracy: 0.7500 - val_loss: 0.3512 - val_accuracy: 0.8077
# Epoch 144/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2250 - accuracy: 0.9000
# Epoch 144: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.2250 - accuracy: 0.9000 - val_loss: 0.3634 - val_accuracy: 0.8077
# Epoch 145/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3190 - accuracy: 0.8500
# Epoch 145: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.3190 - accuracy: 0.8500 - val_loss: 0.3520 - val_accuracy: 0.8077
# Epoch 146/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2023 - accuracy: 0.9500
# Epoch 146: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.2023 - accuracy: 0.9500 - val_loss: 0.3415 - val_accuracy: 0.8077
# Epoch 147/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1994 - accuracy: 0.9500
# Epoch 147: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.1994 - accuracy: 0.9500 - val_loss: 0.3309 - val_accuracy: 0.8269
# Epoch 148/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3703 - accuracy: 0.7500
# Epoch 148: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.3703 - accuracy: 0.7500 - val_loss: 0.3108 - val_accuracy: 0.8462
# Epoch 149/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1888 - accuracy: 1.0000
# Epoch 149: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.1888 - accuracy: 1.0000 - val_loss: 0.3331 - val_accuracy: 0.8077
# Epoch 150/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5269 - accuracy: 0.8000
# Epoch 150: saving model to best_weights.hdf5
# 1/1 [==============================] - 10s 17s/step - loss: 0.5269 - accuracy: 0.8000 - val_loss: 0.3951 - val_accuracy: 0.7885
# Epoch 151/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3446 - accuracy: 0.8000
# Epoch 151: saving model to best_weights.hdf5
# 1/1 [==============================] - 6s 9s/step - loss: 0.3446 - accuracy: 0.8000 - val_loss: 0.3856 - val_accuracy: 0.8077
# Epoch 152/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3855 - accuracy: 0.8000
# Epoch 152: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.3855 - accuracy: 0.8000 - val_loss: 0.2833 - val_accuracy: 0.8462
# Epoch 153/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3224 - accuracy: 0.9000
# Epoch 153: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.3224 - accuracy: 0.9000 - val_loss: 0.2668 - val_accuracy: 0.9231
# Epoch 154/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2279 - accuracy: 0.9000
# Epoch 154: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.2279 - accuracy: 0.9000 - val_loss: 0.2586 - val_accuracy: 0.9231
# Epoch 155/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4088 - accuracy: 0.8000
# Epoch 155: saving model to best_weights.hdf5
# 1/1 [==============================] - 12s 20s/step - loss: 0.4088 - accuracy: 0.8000 - val_loss: 0.2501 - val_accuracy: 0.9038
# Epoch 156/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2208 - accuracy: 0.9500
# Epoch 156: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.2208 - accuracy: 0.9500 - val_loss: 0.2416 - val_accuracy: 0.9038
# Epoch 157/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1778 - accuracy: 0.9500
# Epoch 157: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.1778 - accuracy: 0.9500 - val_loss: 0.2319 - val_accuracy: 0.9231
# Epoch 158/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2779 - accuracy: 0.9500
# Epoch 158: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.2779 - accuracy: 0.9500 - val_loss: 0.2278 - val_accuracy: 0.9231
# Epoch 159/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2998 - accuracy: 0.9500
# Epoch 159: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 7s/step - loss: 0.2998 - accuracy: 0.9500 - val_loss: 0.2665 - val_accuracy: 0.8462
# Epoch 160/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4950 - accuracy: 0.8000
# Epoch 160: saving model to best_weights.hdf5
# 1/1 [==============================] - 13s 23s/step - loss: 0.4950 - accuracy: 0.8000 - val_loss: 0.2462 - val_accuracy: 0.8462
# Epoch 161/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2188 - accuracy: 0.9000
# Epoch 161: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.2188 - accuracy: 0.9000 - val_loss: 0.2096 - val_accuracy: 0.9423
# Epoch 162/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2136 - accuracy: 0.9500
# Epoch 162: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.2136 - accuracy: 0.9500 - val_loss: 0.2156 - val_accuracy: 0.8846
# Epoch 163/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3391 - accuracy: 0.8500
# Epoch 163: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 9s/step - loss: 0.3391 - accuracy: 0.8500 - val_loss: 0.2031 - val_accuracy: 0.9231
# Epoch 164/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1479 - accuracy: 1.0000
# Epoch 164: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.1479 - accuracy: 1.0000 - val_loss: 0.2604 - val_accuracy: 0.9038
# Epoch 165/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5885 - accuracy: 0.7000
# Epoch 165: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.5885 - accuracy: 0.7000 - val_loss: 0.2090 - val_accuracy: 0.9423
# Epoch 166/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3005 - accuracy: 0.9000
# Epoch 166: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.3005 - accuracy: 0.9000 - val_loss: 0.2210 - val_accuracy: 0.8846
# Epoch 167/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1897 - accuracy: 0.9500
# Epoch 167: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.1897 - accuracy: 0.9500 - val_loss: 0.2115 - val_accuracy: 0.9038
# Epoch 168/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2448 - accuracy: 0.9500
# Epoch 168: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.2448 - accuracy: 0.9500 - val_loss: 0.4305 - val_accuracy: 0.8077
# Epoch 169/500
# 2/1 [======================================] - ETA: 0s - loss: 0.5417 - accuracy: 0.7500
# Epoch 169: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.5417 - accuracy: 0.7500 - val_loss: 0.4309 - val_accuracy: 0.8077
# Epoch 170/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3120 - accuracy: 0.9000
# Epoch 170: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.3120 - accuracy: 0.9000 - val_loss: 0.2364 - val_accuracy: 0.8462
# Epoch 171/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1597 - accuracy: 0.9500
# Epoch 171: saving model to best_weights.hdf5
# 1/1 [==============================] - 9s 16s/step - loss: 0.1597 - accuracy: 0.9500 - val_loss: 0.1878 - val_accuracy: 0.9423
# Epoch 172/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1898 - accuracy: 1.0000
# Epoch 172: saving model to best_weights.hdf5
# 1/1 [==============================] - 6s 9s/step - loss: 0.1898 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9423
# Epoch 173/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3227 - accuracy: 0.8500
# Epoch 173: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 9s/step - loss: 0.3227 - accuracy: 0.8500 - val_loss: 0.3045 - val_accuracy: 0.8846
# Epoch 174/500
# 2/1 [======================================] - ETA: 0s - loss: 0.6066 - accuracy: 0.8000
# Epoch 174: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.6066 - accuracy: 0.8000 - val_loss: 0.2857 - val_accuracy: 0.8846
# Epoch 175/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2603 - accuracy: 0.8750
# Epoch 175: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 9s/step - loss: 0.2603 - accuracy: 0.8750 - val_loss: 0.2014 - val_accuracy: 0.8846
# Epoch 176/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1819 - accuracy: 0.9500
# Epoch 176: saving model to best_weights.hdf5
# ...
# Epoch 443/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3766 - accuracy: 0.8500
# Epoch 443: saving model to best_weights.hdf5
# 1/1 [==============================] - 7s 12s/step - loss: 0.3766 - accuracy: 0.8500 - val_loss: 0.0282 - val_accuracy: 1.0000
# Epoch 444/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1268 - accuracy: 0.9000
# Epoch 444: saving model to best_weights.hdf5
# 1/1 [==============================] - 11s 18s/step - loss: 0.1268 - accuracy: 0.9000 - val_loss: 0.0186 - val_accuracy: 1.0000
# Epoch 445/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1068 - accuracy: 1.0000
# Epoch 445: saving model to best_weights.hdf5
# 1/1 [==============================] - 6s 11s/step - loss: 0.1068 - accuracy: 1.0000 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 446/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0241 - accuracy: 1.0000
# Epoch 446: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.0241 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 0.9808
# Epoch 447/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1131 - accuracy: 0.9500
# Epoch 447: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.1131 - accuracy: 0.9500 - val_loss: 0.0440 - val_accuracy: 0.9808
# Epoch 448/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0294 - accuracy: 1.0000
# Epoch 448: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.0294 - accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 1.0000
# Epoch 449/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0298 - accuracy: 1.0000
# Epoch 449: saving model to best_weights.hdf5
# 1/1 [==============================] - 8s 13s/step - loss: 0.0298 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 450/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0432 - accuracy: 1.0000
# Epoch 450: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.0432 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 451/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1695 - accuracy: 0.8500
# Epoch 451: saving model to best_weights.hdf5
# 1/1 [==============================] - 9s 16s/step - loss: 0.1695 - accuracy: 0.8500 - val_loss: 0.0239 - val_accuracy: 1.0000
# Epoch 452/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0877 - accuracy: 0.9500
# Epoch 452: saving model to best_weights.hdf5
# 1/1 [==============================] - 7s 11s/step - loss: 0.0877 - accuracy: 0.9500 - val_loss: 0.0338 - val_accuracy: 0.9808
# Epoch 453/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1044 - accuracy: 0.9375
# Epoch 453: saving model to best_weights.hdf5
# 1/1 [==============================] - 11s 18s/step - loss: 0.1044 - accuracy: 0.9375 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 454/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0143 - accuracy: 1.0000
# Epoch 454: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 1.0000
# Epoch 455/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0620 - accuracy: 0.9375
# Epoch 455: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 9s/step - loss: 0.0620 - accuracy: 0.9375 - val_loss: 0.0287 - val_accuracy: 1.0000
# Epoch 456/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0760 - accuracy: 0.9500
# Epoch 456: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.0760 - accuracy: 0.9500 - val_loss: 0.0210 - val_accuracy: 1.0000
# Epoch 457/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0271 - accuracy: 1.0000
# Epoch 457: saving model to best_weights.hdf5
# 1/1 [==============================] - 11s 18s/step - loss: 0.0271 - accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 1.0000
# Epoch 458/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1876 - accuracy: 0.9500
# Epoch 458: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.1876 - accuracy: 0.9500 - val_loss: 0.0280 - val_accuracy: 1.0000
# Epoch 459/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1348 - accuracy: 0.9500
# Epoch 459: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.1348 - accuracy: 0.9500 - val_loss: 0.0347 - val_accuracy: 1.0000
# Epoch 460/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1029 - accuracy: 1.0000
# Epoch 460: saving model to best_weights.hdf5
# 1/1 [==============================] - 9s 15s/step - loss: 0.1029 - accuracy: 1.0000 - val_loss: 0.5943 - val_accuracy: 0.8846
# Epoch 461/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2982 - accuracy: 0.9000
# Epoch 461: saving model to best_weights.hdf5
# 1/1 [==============================] - 6s 10s/step - loss: 0.2982 - accuracy: 0.9000 - val_loss: 0.0159 - val_accuracy: 1.0000
# Epoch 462/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0283 - accuracy: 1.0000
# Epoch 462: saving model to best_weights.hdf5
# 1/1 [==============================] - 6s 11s/step - loss: 0.0283 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 463/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0218 - accuracy: 1.0000
# Epoch 463: saving model to best_weights.hdf5
# 1/1 [==============================] - 11s 19s/step - loss: 0.0218 - accuracy: 1.0000 - val_loss: 0.0520 - val_accuracy: 0.9808
# Epoch 464/500
# 2/1 [======================================] - ETA: 0s - loss: 0.4498 - accuracy: 0.9000
# Epoch 464: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.4498 - accuracy: 0.9000 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 465/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9500
# Epoch 465: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.1100 - accuracy: 0.9500 - val_loss: 0.0152 - val_accuracy: 1.0000
# Epoch 466/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0216 - accuracy: 1.0000
# Epoch 466: saving model to best_weights.hdf5
# 1/1 [==============================] - 8s 14s/step - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 467/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0103 - accuracy: 1.0000
# Epoch 467: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0194 - val_accuracy: 1.0000
# Epoch 468/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9375
# Epoch 468: saving model to best_weights.hdf5
# 1/1 [==============================] - 7s 12s/step - loss: 0.0844 - accuracy: 0.9375 - val_loss: 0.0258 - val_accuracy: 1.0000
# Epoch 469/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0515 - accuracy: 1.0000
# Epoch 469: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 0.1064 - val_accuracy: 0.9808
# Epoch 470/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1106 - accuracy: 0.9500
# Epoch 470: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.1106 - accuracy: 0.9500 - val_loss: 0.1168 - val_accuracy: 0.9808
# Epoch 471/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0342 - accuracy: 1.0000
# Epoch 471: saving model to best_weights.hdf5
# 1/1 [==============================] - 10s 18s/step - loss: 0.0342 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 472/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0255 - accuracy: 1.0000
# Epoch 472: saving model to best_weights.hdf5
# 1/1 [==============================] - 10s 17s/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 473/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0144 - accuracy: 1.0000
# Epoch 473: saving model to best_weights.hdf5
# 1/1 [==============================] - 6s 11s/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 1.0000
# Epoch 474/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1143 - accuracy: 0.8750
# Epoch 474: saving model to best_weights.hdf5
# 1/1 [==============================] - 8s 13s/step - loss: 0.1143 - accuracy: 0.8750 - val_loss: 0.0151 - val_accuracy: 1.0000
# Epoch 475/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0339 - accuracy: 1.0000
# Epoch 475: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.0339 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 476/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1961 - accuracy: 0.9500
# Epoch 476: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 8s/step - loss: 0.1961 - accuracy: 0.9500 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 477/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0169 - accuracy: 1.0000
# Epoch 477: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 478/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9500
# Epoch 478: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.1018 - accuracy: 0.9500 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 479/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0132 - accuracy: 1.0000
# Epoch 479: saving model to best_weights.hdf5
# 1/1 [==============================] - 10s 18s/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 480/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0433 - accuracy: 1.0000
# Epoch 480: saving model to best_weights.hdf5
# 1/1 [==============================] - 7s 11s/step - loss: 0.0433 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 481/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0230 - accuracy: 1.0000
# Epoch 481: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 9s/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 482/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0160 - accuracy: 1.0000
# Epoch 482: saving model to best_weights.hdf5
# 1/1 [==============================] - 5s 9s/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 1.0000
# Epoch 483/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 483: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 484/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1659 - accuracy: 0.9500
# Epoch 484: saving model to best_weights.hdf5
# 1/1 [==============================] - 12s 21s/step - loss: 0.1659 - accuracy: 0.9500 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 485/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0512 - accuracy: 0.9500
# Epoch 485: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.0512 - accuracy: 0.9500 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 486/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0475 - accuracy: 0.9500
# Epoch 486: saving model to best_weights.hdf5
# 1/1 [==============================] - 9s 15s/step - loss: 0.0475 - accuracy: 0.9500 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 487/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0434 - accuracy: 1.0000
# Epoch 487: saving model to best_weights.hdf5
# 1/1 [==============================] - 7s 12s/step - loss: 0.0434 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 488/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0276 - accuracy: 1.0000
# Epoch 488: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.0276 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 489/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0192 - accuracy: 1.0000
# Epoch 489: saving model to best_weights.hdf5
# 1/1 [==============================] - 9s 15s/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 0.9808
# Epoch 490/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0834 - accuracy: 0.9500
# Epoch 490: saving model to best_weights.hdf5
# 1/1 [==============================] - 15s 26s/step - loss: 0.0834 - accuracy: 0.9500 - val_loss: 0.0207 - val_accuracy: 0.9808
# Epoch 491/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0085 - accuracy: 1.0000
# Epoch 491: saving model to best_weights.hdf5
# 1/1 [==============================] - 6s 11s/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 492/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2902 - accuracy: 0.9500
# Epoch 492: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.2902 - accuracy: 0.9500 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 493/500
# 2/1 [======================================] - ETA: 0s - loss: 0.1145 - accuracy: 0.9375
# Epoch 493: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.1145 - accuracy: 0.9375 - val_loss: 0.0365 - val_accuracy: 0.9808
# Epoch 494/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0475 - accuracy: 1.0000
# Epoch 494: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 5s/step - loss: 0.0475 - accuracy: 1.0000 - val_loss: 0.0819 - val_accuracy: 0.9808
# Epoch 495/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0451 - accuracy: 1.0000
# Epoch 495: saving model to best_weights.hdf5
# 1/1 [==============================] - 7s 12s/step - loss: 0.0451 - accuracy: 1.0000 - val_loss: 0.0914 - val_accuracy: 0.9808
# Epoch 496/500
# 2/1 [======================================] - ETA: 0s - loss: 0.2224 - accuracy: 0.9000
# Epoch 496: saving model to best_weights.hdf5
# 1/1 [==============================] - 7s 12s/step - loss: 0.2224 - accuracy: 0.9000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 497/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0605 - accuracy: 0.9500
# Epoch 497: saving model to best_weights.hdf5
# 1/1 [==============================] - 3s 6s/step - loss: 0.0605 - accuracy: 0.9500 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 498/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0227 - accuracy: 1.0000
# Epoch 498: saving model to best_weights.hdf5
# 1/1 [==============================] - 12s 20s/step - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.0479 - val_accuracy: 0.9808
# Epoch 499/500
# 2/1 [======================================] - ETA: 0s - loss: 0.3406 - accuracy: 0.9000
# Epoch 499: saving model to best_weights.hdf5
# 1/1 [==============================] - 7s 12s/step - loss: 0.3406 - accuracy: 0.9000 - val_loss: 0.0414 - val_accuracy: 0.9808
# Epoch 500/500
# 2/1 [======================================] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 500: saving model to best_weights.hdf5
# 1/1 [==============================] - 4s 6s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9808

# %%
model2.save_weights("model_weights_hist.h5")
model2.save("model_hist.h5")

# %% [markdown]
# ##Display variation of each epoch in training accuracy and loss function

# %%
# Extract the training history
training_loss = history.history['loss']
training_accuracy = history.history['accuracy']
validation_loss = history.history['val_loss']
validation_accuracy = history.history['val_accuracy']

# Create a figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(9, 5))

# Plot the training and validation loss
axs[0].plot(range(1, N_epochs + 1), training_loss, label='Training Loss', color='cyan')
axs[0].plot(range(1, N_epochs + 1), validation_loss, label='Validation Loss', color='purple')
axs[0].set_title('Training and Validation Loss')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')
axs[0].legend()

# Plot the training and validation accuracy
axs[1].plot(range(1, N_epochs + 1), training_accuracy, label='Training Accuracy', color='cyan')
axs[1].plot(range(1, N_epochs + 1), validation_accuracy, label='Validation Accuracy', color='purple')
axs[1].set_title('Training and Validation Accuracy')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Accuracy')
axs[1].legend()

# Adjust the spacing between subplots
plt.tight_layout()
# Show the figure
plt.show()

# %% [markdown]
# ##Display model2 performance metrics

# %%
# Convert true labels to binary format
y_test_binary = np.argmax(y_test, axis=1)

# Evaluate the model on the test set
test_loss, test_accuracy = model2.evaluate(x_test, y_test, verbose=0)

# Predict the labels for the test set
y_pred_classes = np.argmax(model2.predict(x_test), axis=1)

# Compute model performance metrics
classification_rep = classification_report(y_test_binary, y_pred_classes)
confusion_mat = confusion_matrix(y_test_binary, y_pred_classes)
true_negative, false_positive, _, _ = confusion_mat.ravel()
specificity = true_negative / (true_negative + false_positive)

# Print model performance metrics
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Classification Report:")
print(classification_rep)
print("Confusion Matrix:")
print(confusion_mat)
print("Test Specificity:", specificity)

# Define the class labels
class_labels = ['Normal', 'Abnormal']

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(6, 6))
sns.heatmap(confusion_mat, annot=True, cmap='Blues', fmt='d', xticklabels=class_labels, yticklabels=class_labels)
ax.set_xlabel('Predicted Labels')
ax.set_ylabel('True Labels')
ax.set_title('Confusion Matrix')
plt.show()
# Out:
# 2/2 [==============================] - 1s 96ms/step
# Test Loss: 0.07028546929359436
# Test Accuracy: 0.9615384340286255
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        26
#            1       0.96      0.96      0.96        26
#
#     accuracy                           0.96        52
#    macro avg       0.96      0.96      0.96        52
# weighted avg       0.96      0.96      0.96        52
#
# Confusion Matrix:
# [[25  1]
#  [ 1 25]]
# Test Specificity: 0.9615384615384616
